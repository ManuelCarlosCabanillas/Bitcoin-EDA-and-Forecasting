# %%
# Run the pip install command below if you don't already have the library
#!pip install git+https://github.com/JustAnotherArchivist/snscrape.git
#!pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Run the below command if you don't already have Pandas
#!pip install pandas

# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd
import time
import tqdm

# %%
## Búsqueda por usuario

# Setting variables to be used below
maxTweets = 100

# Creating list to append tweet data to
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:jack').get_items()):
    if i>maxTweets:
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# Creating a dataframe from the tweets list above
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# Display first 5 entries from dataframe
tweets_df1.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2022-03-25 00:04:08+00:00  1507146276416098307
# 1 2022-03-20 00:27:17+00:00  1505340163177816069
# 2 2022-03-20 00:26:54+00:00  1505340065127571457
# 3 2022-03-19 20:48:44+00:00  1505285163089018892
# 4 2022-03-18 02:44:58+00:00  1504650038441816066
#
#                                                 Text Username
# 0  The choice of which algorithm to use (or not) ...     jack
# 1                                      @surferjimw 💯     jack
# 2               @surferjimw he was an incredible man     jack
# 3                            https://t.co/TGorbzFF98     jack
# 4            https://t.co/Su9uic6BvB 🌊@thevibesrgood     jack

# %%
# Export dataframe into a CSV
tweets_df1.to_csv('user-tweets.csv', sep=',', index=False)

# %% [markdown]
# ## LOAD/SAVE

# %%
# Export dataframe into a CSV
#tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
tweets_df2 = pd.read_csv('text-query-tweets.csv')

# %%
tweets_df2['Datetime']
# Out:
# 0         2022-03-14 23:59:19+00:00
# 1         2022-03-14 23:59:18+00:00
# 2         2022-03-14 23:59:00+00:00
# 3         2022-03-14 23:57:48+00:00
# 4         2022-03-14 23:57:45+00:00
#                     ...
# 794116    2020-04-06 00:55:55+00:00
# 794117    2020-04-06 00:54:05+00:00
# 794118    2020-04-06 00:53:09+00:00
# 794119    2020-04-06 00:50:12+00:00
# 794120    2020-04-06 00:48:16+00:00
# Name: Datetime, Length: 794121, dtype: object

# %%
## Búsqueda por texto

good_users=0
# Setting variables to be used below
maxTweets = 5000000

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#Bitcoin since:2022-03-15 until:2022-03-29 lang:es').get_items()):
    
    if i>maxTweets:
        break
    elif i%1000==0:
        print(i)
    #if tweet.likeCount>=0:
    a=tweet
    #good_users+=1
    #print(good_users)
    tweets_list2.append([tweet.date, 
                         tweet.id, 
                         tweet.content, 
                         tweet.user.username,
                         tweet.user.followersCount,
                         tweet.user.friendsCount,
                         tweet.replyCount,
                         tweet.retweetCount,
                         tweet.likeCount,
                         tweet.quoteCount, 
                         tweet.retweetedTweet, 
                         tweet.quotedTweet, 
                         tweet.inReplyToTweetId,
                         tweet.inReplyToUser, 
                         tweet.mentionedUsers,
                         ])
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000

# %%
tweets_df1 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'followersCount',
                         'friendsCount',
                         'replyCount',
                         'retweetCount',
                         'likeCount',
                         'quoteCount', 
                         'retweetedTweetone', 
                         'quotedTweet', 
                         'inReplyToTweetId',
                         'inReplyToUser', 
                         'mentionedUsers'])
tweets_df2= pd.concat([tweets_df2, tweets_df1])

# %%
tweets_df2
# Out:
#                         Datetime             Tweet Id  \
# 0      2022-03-14 23:59:19+00:00  1503521184327077896
# 1      2022-03-14 23:59:18+00:00  1503521180698955777
# 2      2022-03-14 23:59:00+00:00  1503521105293692929
# 3      2022-03-14 23:57:48+00:00  1503520805434572803
# 4      2022-03-14 23:57:45+00:00  1503520790104485889
# ...                          ...                  ...
# 19991  2022-03-15 00:02:25+00:00  1503521968129196032
# 19992  2022-03-15 00:01:05+00:00  1503521631733526528
# 19993  2022-03-15 00:00:32+00:00  1503521490976874498
# 19994  2022-03-15 00:00:11+00:00  1503521403609440266
# 19995  2022-03-15 00:00:02+00:00  1503521365692932097
#
#                                                     Text         Username  \
# 0        #Bitcoin  Consolidation https://t.co/kKkidBe8oU   sweetslr1nonly
# 1      Elon Musk ha anunciado que tiene #Bitcoin, #Et...     cryptobcncat
# 2      #ELSALVADOR | El país centroamericano se alist...       stereoscl_
# ...

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'followersCount',
                         'friendsCount',
                         'replyCount',
                         'retweetCount',
                         'likeCount',
                         'quoteCount', 
                         'retweetedTweetone', 
                         'quotedTweet', 
                         'inReplyToTweetId',
                         'inReplyToUser', 
                         'mentionedUsers'])

# Display first 5 entries from dataframe

# %%
# sorting by first name
tweets_df2.sort_values("Tweet Id", inplace = True)
 
# dropping ALL duplicate values
tweets_df2.drop_duplicates(subset ="Tweet Id",
                     keep = False, inplace = True)

# %%
tweets_df2 = tweets_df2.reset_index()
# Out:
#         index                   Datetime             Tweet Id  \
# 0       47460  2020-01-01 00:00:03+00:00  1212161527605858304
# 1       47459  2020-01-01 00:00:57+00:00  1212161752751845376
# 2       47458  2020-01-01 00:10:50+00:00  1212164240607498242
# 3       47457  2020-01-01 00:17:22+00:00  1212165885772935168
# 4       47456  2020-01-01 00:18:01+00:00  1212166047392026624
# ...       ...                        ...                  ...
# 861068      4  2022-03-28 23:53:00+00:00  1508593025475178499
# 861069      3  2022-03-28 23:53:29+00:00  1508593150205607941
# 861070      2  2022-03-28 23:54:16+00:00  1508593343504265220
# 861071      1  2022-03-28 23:57:16+00:00  1508594098680311828
# 861072      0  2022-03-28 23:59:14+00:00  1508594595936063489
#
#                                                      Text         Username  \
# 0       Precio actual del #Bitcoin, #Ethereum y #Rippl...         bitapeso
# ...

# %%
tweets_df2 = tweets_df2.drop(['index'],axis=1)
tweets_df2
# Out:
#                          Datetime             Tweet Id  \
# 0       2020-01-01 00:00:03+00:00  1212161527605858304
# 1       2020-01-01 00:00:57+00:00  1212161752751845376
# 2       2020-01-01 00:10:50+00:00  1212164240607498242
# 3       2020-01-01 00:17:22+00:00  1212165885772935168
# 4       2020-01-01 00:18:01+00:00  1212166047392026624
# ...                           ...                  ...
# 861068  2022-03-28 23:53:00+00:00  1508593025475178499
# 861069  2022-03-28 23:53:29+00:00  1508593150205607941
# 861070  2022-03-28 23:54:16+00:00  1508593343504265220
# 861071  2022-03-28 23:57:16+00:00  1508594098680311828
# 861072  2022-03-28 23:59:14+00:00  1508594595936063489
#
#                                                      Text         Username  \
# 0       Precio actual del #Bitcoin, #Ethereum y #Rippl...         bitapeso
# 1       [-Youtuber (ES)-] Hablando de #Bitcoin y #Crip...   bitcoinertoday
# 2       El precio de 1 btc es 6396.5965 EUR (-0.243%) ...     Curroquevedo
# ...

# %% [markdown]
# FIRST STAGE
# Phase One	tweets per day
# 167	4
# 133	5
# 250	3
# 233	4
# 367	4
# 250	3
# 167	7
# 100	4
# 133	4
# 200	4
# 300	4
# 167	4
# 133	6
# 133	3
# 333	5
# 267	4
# 3333
# ![image.png](attachment:image.png)

# %%
tweets_per_day_1 = 4
tweets_per_day_2 = 5
tweets_per_day_3 = 3
tweets_per_day_4 = 4
tweets_per_day_5 = 4
tweets_per_day_6 = 3
tweets_per_day_7 = 7
tweets_per_day_8 = 4
tweets_per_day_9 = 4
tweets_per_day_10 = 4
tweets_per_day_11 = 4
tweets_per_day_12 = 4
tweets_per_day_13 = 6
tweets_per_day_14 = 3
tweets_per_day_15 = 5
tweets_per_day_16 = 4

# %%
from datetime import date, timedelta

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2013, 1, 1)
end_date = date(2015, 6, 2)
for single_date in daterange(start_date, end_date):
    print(single_date.strftime("%Y-%m-%d"))
# Out:
# 2013-01-01
# 2013-01-02
# 2013-01-03
# 2013-01-04
# 2013-01-05
# 2013-01-06
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-12
# 2013-01-13
# 2013-01-14
# 2013-01-15
# 2013-01-16
# 2013-01-17
# 2013-01-18
# 2013-01-19
# 2013-01-20
# 2013-01-21
# 2013-01-22
# 2013-01-23
# 2013-01-24
# 2013-01-25
# 2013-01-26
# 2013-01-27
# 2013-01-28
# 2013-01-29
# 2013-01-30
# 2013-01-31
# 2013-02-01
# 2013-02-02
# 2013-02-03
# 2013-02-04
# 2013-02-05
# 2013-02-06
# 2013-02-07
# 2013-02-08
# 2013-02-09
# 2013-02-10
# 2013-02-11
# 2013-02-12
# 2013-02-13
# 2013-02-14
# 2013-02-15
# 2013-02-16
# 2013-02-17
# 2013-02-18
# 2013-02-19
# 2013-02-20
# 2013-02-21
# 2013-02-22
# 2013-02-23
# 2013-02-24
# 2013-02-25
# 2013-02-26
# 2013-02-27
# 2013-02-28
# 2013-03-01
# 2013-03-02
# 2013-03-03
# 2013-03-04
# 2013-03-05
# 2013-03-06
# 2013-03-07
# 2013-03-08
# 2013-03-09
# 2013-03-10
# 2013-03-11
# 2013-03-12
# 2013-03-13
# 2013-03-14
# 2013-03-15
# 2013-03-16
# 2013-03-17
# ...

# %%
grouped_by_followers = tweets_df2.groupby(['Username']).agg({'Tweet Id':'size','followersCount':'max','likeCount':'sum'})

grouped_by_followers = pd.DataFrame(grouped_by_followers.sort_values('followersCount')).tail(100)

grouped_by_followers["likes per message"]=grouped_by_followers["likeCount"]/grouped_by_followers["Tweet Id"]

grouped_by_followers.sort_values('likes per message').tail(100)
# Out:
#                 Tweet Id  followersCount  likeCount  likes per message
# Username
# Hurriyet               1         4309967          0           0.000000
# BoletinViajes          6         1294148          3           0.500000
# FraseSimple          160         4466647        180           1.125000
# UNoticias             10         4423838         12           1.200000
# DolarToday           168         3924209        227           1.351190
# ...                  ...             ...        ...                ...
# 100trillionUSD         1         1785992       5052        5052.000000
# ladivaza               1         4806814       5529        5529.000000
# nayibbukele           74         3690080     516879        6984.851351
# cz_binance             1         5473060      22185       22185.000000
# WillyrexYT             1         8127394      36545       36545.000000
#
# [100 rows x 4 columns]

# %%
tweets_df2['Text'].loc[tweets_df2['Username']=="DolarToday"]
# Out:
# 233901    ¡Impresionante! 🤔Murió un multimillonario en #...
# 245359    ¡Impresionante! 🤔Murió un multimillonario en #...
# 263301    #Bitcoin: China declara ilegales todas las tra...
# 288981    #Atencion  Este jueves finalizó la Conferencia...
# 291091    #Atencion 🚨#Bitcoin | Caida abrupta alcanza ha...
#                                 ...
# 573654    ¡Insuperable! 😱El #bitcoin continúa en aumento...
# 577663    ¡Insuperable! 😱El #bitcoin marcó otro récord: ...
# 578410    ¡Insuperable! 😱El #bitcoin marcó otro récord: ...
# 578431    ¡ATENCIÓN!|📣 😱 ¡Asombroso! ¡Insuperable! 😱El #...
# 578578    ¡Insuperable! 😱El #bitcoin marcó otro récord: ...
# Name: Text, Length: 168, dtype: object

# %%
keywords=['#Bitcoin']
start='2020–10–01'
end ='2020–10–03'
max_num=1000
fname='tweet.json'
languages=['es']

# %%
# !pip install langdetect
import snscrape.modules.twitter as sntwitter
import json
from langdetect import detect
# Out:
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=aabf64279719a94a038c33904c7eb74aad755f677979c70729ecd707e668aa14
#   Stored in directory: c:\users\manue\appdata\local\pip\cache\wheels\13\c7\b0\79f66658626032e78fc1a83103690ef6797d551cb22e56e734
# Successfully built langdetect
# ...

# %%
for keyword in keywords:
    for i, tweet in enumerate (sntwitter.TwitterSearchScraper(f'{keyword} + since:{start} until:{end}').get_items()):
        try:
            lan=detect(tweet.content)
        except:
            lan='error'
        if i == max_num:
            break
        if lan in languages:
            data = {'id': tweet.id, 'username':tweet.username, 'date': tweet.date, 'text': tweet.content,'url':tweet.url}
            with open(fname, 'a+', encoding='utf-8') as f:
                line = json.dumps(data, ensure_ascii=False,default=str)
                f.write(line)
                f.write('\n')

# %%
line
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4064/1298077829.py in <module>
# ----> 1 line
#
# NameError: name 'line' is not defined
