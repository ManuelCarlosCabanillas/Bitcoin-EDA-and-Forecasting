# %% [markdown]
# ## Import data & libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random
import warnings
warnings.filterwarnings("ignore")
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import RobustScaler,MinMaxScaler,PowerTransformer
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import TimeSeriesSplit
import sklearn.metrics as metrics
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from tqdm import tqdm
from sklearn.linear_model import SGDRegressor,PassiveAggressiveRegressor
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense,Input,Activation,Embedding,LSTM,Concatenate,Flatten,Dropout,Bidirectional
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.optimizers import Adam,RMSprop,Nadam 
from tensorflow.keras import callbacks,Sequential
import tensorflow as tf
from datetime import datetime
import pytz
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras import backend as K
import shutil,os
import pickle

# %%
final_df = pd.read_csv('data/final_df_next.csv').reset_index(drop=True)
final_df
# Out:
#             Date  avg_transaction_value tema90     ISA_9  closing_price  \
# 0     2013-07-17                      0.000000  0.000384       0.000129
# 1     2013-07-18                      0.000000  0.000373       0.000004
# 2     2013-07-19                      0.000000  0.000374       0.000033
# 3     2013-07-20                      0.000000  0.000378       0.000000
# 4     2013-07-21                      0.000000  0.000370       0.000033
# ...          ...                           ...       ...            ...
# 3169  2022-03-21                      0.569964  0.633353       0.606960
# 3170  2022-03-22                      0.565806  0.617205       0.626993
# 3171  2022-03-23                      0.559075  0.615705       0.634985
# 3172  2022-03-24                      0.555650  0.603135       0.651311
# 3173  2022-03-25                      0.555969  0.601186       0.656027
#
#       sf_ratio ema90     ITS_9    ISB_26  SP500_spot bband_lower90  \
# 0           0.000000  0.000000  0.000343                  0.006433
# 1           0.000000  0.000023  0.000310                  0.006433
# 2           0.000000  0.000096  0.000310                  0.006433
# 3           0.000000  0.000105  0.000384                  0.006433
# 4           0.000000  0.000088  0.000384                  0.006433
# ...              ...       ...       ...                       ...
# 3169        0.943800  0.613184  0.657164                  0.877662
# 3170        0.943583  0.620499  0.656750                  0.877862
# 3171        0.943371  0.625165  0.652776                  0.878052
# 3172        0.943165  0.637883  0.642438                  0.878971
# 3173        0.942965  0.654344  0.642438                  0.879968
#
#       MSCIACW_spot ema60    IKS_26    FUTBTC  highest_price  avg_price_usd  \
# 0               0.000291  0.000046  0.000494       0.000116   7.318068e-05
# 1               0.000291  0.000046  0.000494       0.000099   3.920658e-05
# 2               0.000291  0.000046  0.000494       0.000046   0.000000e+00
# 3               0.000291  0.000046  0.000494       0.000016   2.964581e-07
# 4               0.000291  0.000010  0.000494       0.000000   7.559681e-07
# ...                  ...       ...       ...            ...            ...
# 3169            0.872834  0.626170  0.604342       0.601464   6.079786e-01
# 3170            0.873765  0.647479  0.621874       0.627529   6.277079e-01
# 3171            0.874218  0.647479  0.619776       0.623162   6.249805e-01
# 3172            0.875157  0.647479  0.645474       0.640927   6.409448e-01
# 3173            0.876132  0.648423  0.653551       0.653424   6.550265e-01
#
#       lowest_price  market_cap_usd  opening_price  Social_Volume ema30  \
# 0         0.000151    4.371556e-05       0.000108             0.005444
# 1         0.000000    2.346941e-05       0.000129             0.005444
# 2         0.000021    0.000000e+00       0.000004             0.005444
# 3         0.000047    4.565294e-07       0.000033             0.005444
# 4         0.000027    1.041197e-06       0.000000             0.005444
# ...            ...             ...            ...                  ...
# 3169      0.610484    6.120807e-01       0.610808             0.607651
# 3170      0.615964    6.319671e-01       0.606952             0.603509
# 3171      0.629579    6.292423e-01       0.626985             0.595206
# 3172      0.642606    6.453432e-01       0.634963             0.590135
# 3173      0.657157    6.595433e-01       0.651304             0.585351
#
#       next_day_closing_price
# 0                       90.1
# 1                       92.0
# 2                       89.8
# 3                       92.0
# 4                       91.6
# ...                      ...
# 3169                 42373.0
# 3170                 42912.0
# 3171                 44013.0
# 3172                 44331.0
# 3173                 44548.0
#
# [3174 rows x 18 columns]

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def calculate_metrics(y, ypred):
    MAE = metrics.mean_absolute_error(y, ypred)
    RMSE = metrics.mean_squared_error(y, ypred,squared=False)
    return MAE,RMSE

def plot_results(y,ypred,title=None):
    plt.figure(figsize=(25,5))
    plt.plot(y,label='actual')
    plt.plot(ypred,label='predicted')
    plt.legend()
    plt.grid()
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Train Test Split

# %%
train_window = 500
test_window = 100
train_splits = []
test_splits = []
for i in tqdm(range(train_window, len(final_df),test_window)):
    train_split = final_df[i-train_window:i]
    test_split = final_df[i:i+test_window]
    train_splits.append(train_split)
    test_splits.append(test_split)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 27/27 [00:00<00:00, 26969.80it/s]

# %%
len(test_splits)*100
# Out:
# 2700

# %%
def visualize_split(batch_no,show_plot=True):
    final_df.plot(x='Date',y='next_day_closing_price',figsize=(25,5))
    for i in range(train_splits[batch_no].index[0],train_splits[batch_no].index[-1]):
        plt.axvline(x=i,color='r',alpha=0.1)
    for i in range(test_splits[batch_no].index[0],test_splits[batch_no].index[-1]):
        plt.axvline(x=i,color='b',alpha=0.1)
    plt.grid()
    plt.legend('')
    plt.title(f'Temporal Window Split-{batch_no+1}')
    if not os.path.exists('/content/plot'):
        os.makedirs('/content/plot')
        
    plt.savefig(f'/content/plot/Temporal Window Split-{batch_no+1}.png')
    plt.show()

# %%
for i in range(len(train_splits)):
    visualize_split(i)

# %%
visualize_split(-1)

# %%
import shutil
shutil.make_archive('plot', 'zip', '/content/plot')
# Out:
# 'C:\\Users\\manue\\trabajo\\btc\\plot.zip'

# %% [markdown]
# ## Dummy Regressor

# %%
dmy_date_array = []
dmy_y_test_array = []
dmy_y_test_pred_array = []
dmy_batch_id_array = []
dmy_batch_id_array_result = []
dmy_batch_mae_train_array = []
dmy_batch_rmse_train_array = []
dmy_batch_mae_test_array = []
dmy_batch_rmse_test_array = []

for i in tqdm(range(len(train_splits))):
    Xtrain_split = train_splits[i].drop(['next_day_closing_price','Date'],axis=1).values
    Xtest_split = test_splits[i].drop(['next_day_closing_price','Date'],axis=1).values

    ytrain_split = train_splits[i]['next_day_closing_price'].reset_index(drop=True).values
    ytest_split = test_splits[i]['next_day_closing_price'].reset_index(drop=True).values

    dmy = DummyRegressor(strategy="quantile",quantile=0.9)
    dmy.fit(Xtrain_split, ytrain_split)

    ytrain_pred = dmy.predict(Xtrain_split)
    ytest_pred = dmy.predict(Xtest_split)

    MAE_train,RMSE_train = calculate_metrics(ytrain_split,ytrain_pred)
    MAE_test,RMSE_test = calculate_metrics(ytest_split,ytest_pred)

    dmy_date_array.extend(test_splits[i]['Date'])
    dmy_y_test_array.extend(test_splits[i]['next_day_closing_price'])
    dmy_y_test_pred_array.extend((ytest_pred.flatten()))
    dmy_batch_id_array.extend([i]*len(test_splits[i]))

    dmy_batch_id_array_result.append(i)
    dmy_batch_mae_train_array.append(MAE_train)
    dmy_batch_rmse_train_array.append(RMSE_train)

    dmy_batch_mae_test_array.append(MAE_test)
    dmy_batch_rmse_test_array.append(RMSE_test)

dmy_result_test_df = pd.DataFrame()
dmy_result_test_df['batch_id'] = dmy_batch_id_array
dmy_result_test_df['Date'] = dmy_date_array
dmy_result_test_df['y_test'] = dmy_y_test_array
dmy_result_test_df['y_test_pred'] = dmy_y_test_pred_array
dmy_y_test_array = dmy_result_test_df['y_test']
dmy_y_test_pred_array = dmy_result_test_df['y_test_pred']
dmy_result_metrics_df = pd.DataFrame()
dmy_result_metrics_df['batch_id'] = dmy_batch_id_array_result
dmy_result_metrics_df['mae_train'] = dmy_batch_mae_train_array
dmy_result_metrics_df['rmse_train'] = dmy_batch_rmse_train_array
dmy_result_metrics_df['mae_test'] = dmy_batch_mae_test_array
dmy_result_metrics_df['rmse_test'] = dmy_batch_rmse_test_array
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 797.48it/s]

# %%
plot_results(dmy_y_test_array,dmy_y_test_pred_array,'results-test')

# %%
dmy_result_metrics_df
# Out:
#     batch_id   mae_train    rmse_train      mae_test     rmse_test
# 0          0    424.2466    477.949096    603.458000    605.737882
# 1          1    394.8352    434.770016    638.619000    638.858466
# 2          2    222.3904    261.983535    360.784000    361.514520
# 3          3    250.3464    280.635596    254.750000    265.180381
# 4          4    131.6236    146.292494     20.992200     26.866669
# 5          5    119.3916    139.147534    132.670000    169.865444
# 6          6    199.4684    218.769047     74.299600     80.392548
# 7          7    216.4916    255.832949    184.317000    212.114768
# 8          8    264.2350    302.200857    442.390000    491.457288
# 9          9    499.9478    555.424382   1619.754000   1740.360312
# 10        10   1537.3200   1669.133692   3201.100000   3715.650815
# 11        11   3667.2836   3946.676648   6731.931000   7356.266125
# 12        12   7475.6004   8173.447041   3429.369000   3553.187333
# 13        13   6046.6096   6853.086839   4657.147000   4692.119324
# 14        14   4943.2490   5536.874567   6268.362000   6406.902809
# 15        15   4477.8702   4899.992383   7431.192000   7449.651763
# 16        16   4847.2566   5306.674263   2950.031000   3554.568661
# 17        17   3026.7878   3489.906983   1038.653400   1195.131656
# 18        18   3728.9850   4329.351061   2236.048000   2415.756991
# 19        19   3450.9852   4149.146959   2405.534000   2812.823434
# 20        20   2884.6396   3600.114538   1063.322400   1103.960786
# 21        21   2416.4076   2838.439976   2690.350800   3858.371221
# 22        22   3043.0584   3464.999355  26265.268000  28802.458658
# 23        23  23490.8590  24763.375615  12406.329000  15316.263096
# 24        24  32491.8220  36701.813466  13884.138000  15244.861073
# 25        25  25730.4648  30629.958322   6119.384800   7019.309464
# 26        26  20015.7318  25374.520143  18253.750541  18432.418404

# %%
pd.DataFrame(dmy_result_metrics_df.mean()).drop(['batch_id'],axis=0)
# Out:
#                       0
# mae_train   5777.700267
# rmse_train  6622.241384
# mae_test    4643.109064
# rmse_test   5093.409255

# %%
dmy_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/dmy_result_test_20210922.csv')
dmy_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/dmy_result_metrics_20210922.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12208/1681294249.py in <module>
# ----> 1 dmy_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/dmy_result_test_20210922.csv')
#       2 dmy_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/dmy_result_metrics_20210922.csv')
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/dmy_result_test_20210922.csv'

# %% [markdown]
# ## SVR

# %%
svr_date_array = []
svr_y_test_array = []
svr_y_test_pred_array = []
svr_batch_id_array = []
svr_batch_id_array_result = []
svr_batch_mae_train_array = []
svr_batch_rmse_train_array = []
svr_batch_mae_test_array = []
svr_batch_rmse_test_array = []

for i in tqdm(range(len(train_splits))):
    Xtrain_split = train_splits[i].drop(['next_day_closing_price','Date'],axis=1).values
    Xtest_split = test_splits[i].drop(['next_day_closing_price','Date'],axis=1).values

    ytrain_split = train_splits[i]['next_day_closing_price'].reset_index(drop=True).values
    ytest_split = test_splits[i]['next_day_closing_price'].reset_index(drop=True).values

    svr = SVR(C=10000,gamma='auto',kernel='rbf')
    svr.fit(Xtrain_split, ytrain_split)

    ytrain_pred = svr.predict(Xtrain_split)
    ytest_pred = svr.predict(Xtest_split)

    MAE_train,RMSE_train = calculate_metrics(ytrain_split,ytrain_pred)
    MAE_test,RMSE_test = calculate_metrics(ytest_split,ytest_pred)

    svr_date_array.extend(test_splits[i]['Date'])
    svr_y_test_array.extend(test_splits[i]['next_day_closing_price'])
    svr_y_test_pred_array.extend((ytest_pred.flatten()))
    svr_batch_id_array.extend([i]*len(test_splits[i]))

    svr_batch_id_array_result.append(i)
    svr_batch_mae_train_array.append(MAE_train)
    svr_batch_rmse_train_array.append(RMSE_train)
    svr_batch_mae_test_array.append(MAE_test)
    svr_batch_rmse_test_array.append(RMSE_test)

svr_result_test_df = pd.DataFrame()
svr_result_test_df['batch_id'] = svr_batch_id_array
svr_result_test_df['Date'] = svr_date_array
svr_result_test_df['y_test'] = svr_y_test_array
svr_result_test_df['y_test_pred'] = svr_y_test_pred_array
svr_y_test_array = svr_result_test_df['y_test']
svr_y_test_pred_array = svr_result_test_df['y_test_pred']
svr_result_metrics_df = pd.DataFrame()
svr_result_metrics_df['batch_id'] = svr_batch_id_array_result
svr_result_metrics_df['mae_train'] = svr_batch_mae_train_array
svr_result_metrics_df['rmse_train'] = svr_batch_rmse_train_array
svr_result_metrics_df['mae_test'] = svr_batch_mae_test_array
svr_result_metrics_df['rmse_test'] = svr_batch_rmse_test_array
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 77.45it/s]

# %%
plot_results(svr_y_test_array,svr_y_test_pred_array,'results-test')

# %%
svr_result_metrics_df
# Out:
#     batch_id    mae_train   rmse_train     mae_test    rmse_test
# 0          0    87.911910   150.751510    49.532839    57.550968
# 1          1    86.062955   133.754987    14.930376    17.623254
# 2          2    48.331045    77.062845    58.931592    63.039179
# 3          3    42.118850    55.831708    90.774445   119.013167
# 4          4    41.493469    56.912710   113.548201   117.433209
# 5          5    35.434593    49.339699   152.570304   184.852987
# 6          6    35.668953    53.362285    58.259454    62.251981
# 7          7    36.193911    52.462372   159.517653   180.018441
# 8          8    46.702077    65.710619   135.932325   188.326393
# 9          9    58.418129    93.266248  1287.757231  1400.517263
# 10        10   124.355399   211.983678  1278.531087  1525.307592
# 11        11   162.619086   277.266359  1692.749853  2283.932937
# 12        12   315.274920   644.412566   947.396893  1053.361082
# 13        13   377.405679   666.517842   409.908849   491.106148
# 14        14   402.350982   662.171947   530.464693   561.331528
# 15        15   395.106297   643.744216   215.620591   238.031333
# 16        16   343.691268   665.488993   474.483037   637.578315
# 17        17   271.618074   418.118258   442.575841   557.743297
# 18        18   250.853382   393.385277   314.998933   370.472708
# 19        19   253.112441   386.207307   519.429823   698.128929
# 20        20   285.926444   433.248805   180.102153   248.250155
# 21        21   312.943257   454.307409   742.026718  1013.143020
# 22        22   298.598728   449.094440  6321.152741  7872.533386
# 23        23   555.340473  1071.476963  3164.896439  3708.707100
# 24        24   850.663616  1433.582100  1466.321474  1915.250420
# 25        25  1034.626003  1564.308524  2347.749166  2834.570774
# 26        26  1305.266956  1816.204918  1337.729105  1806.676494

# %%
pd.DataFrame(svr_result_metrics_df.mean()).drop(['batch_id'])
# Out:
#                       0
# mae_train    298.447737
# rmse_train   480.739799
# mae_test     907.699697
# rmse_test   1118.768595

# %%
svr_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/svr_result_test_20210922.csv')
svr_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/svr_result_metrics_20210922.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12208/1592600487.py in <module>
# ----> 1 svr_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/svr_result_test_20210922.csv')
#       2 svr_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/svr_result_metrics_20210922.csv')
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/svr_result_test_20210922.csv'

# %% [markdown]
# ## XGBoost

# %%
xgb_date_array = []
xgb_y_test_array = []
xgb_y_test_pred_array = []
xgb_batch_id_array = []
xgb_batch_id_array_result = []
xgb_batch_mae_train_array = []
xgb_batch_rmse_train_array = []
xgb_batch_mape_train_array = []
xgb_batch_mae_test_array = []
xgb_batch_rmse_test_array = []
xgb_batch_mape_test_array = []
for i in tqdm(range(len(train_splits))):
    Xtrain_split = train_splits[i].drop(['next_day_closing_price','Date'],axis=1)
    Xtest_split = test_splits[i].drop(['next_day_closing_price','Date'],axis=1)
    ytrain_split = train_splits[i]['next_day_closing_price'].reset_index(drop=True).values
    ytest_split = test_splits[i]['next_day_closing_price'].reset_index(drop=True).values

    xgbm_reg = xgb.XGBRegressor(n_estimators=500,max_depth=3,objective='reg:squarederror',
                                learning_rate =0.01,n_jobs=-1)
    xgbm_reg.fit(Xtrain_split, ytrain_split)

    ytrain_pred = xgbm_reg.predict(Xtrain_split)
    ytest_pred = xgbm_reg.predict(Xtest_split)

    MAE_train,RMSE_train = calculate_metrics(ytrain_split,ytrain_pred)
    MAE_test,RMSE_test = calculate_metrics(ytest_split,ytest_pred)

    xgb_date_array.extend(test_splits[i]['Date'])
    xgb_y_test_array.extend(test_splits[i]['next_day_closing_price'])
    xgb_y_test_pred_array.extend((ytest_pred.flatten()))
    xgb_batch_id_array.extend([i]*len(test_splits[i]))

    xgb_batch_id_array_result.append(i)
    xgb_batch_mae_train_array.append(MAE_train)
    xgb_batch_rmse_train_array.append(RMSE_train)
    xgb_batch_mae_test_array.append(MAE_test)
    xgb_batch_rmse_test_array.append(RMSE_test)

xgb_result_test_df = pd.DataFrame()
xgb_result_test_df['batch_id'] = xgb_batch_id_array
xgb_result_test_df['Date'] = xgb_date_array
xgb_result_test_df['y_test'] = xgb_y_test_array
xgb_result_test_df['y_test_pred'] = xgb_y_test_pred_array
xgb_y_test_array = xgb_result_test_df['y_test']
xgb_y_test_pred_array = xgb_result_test_df['y_test_pred']
xgb_result_metrics_df = pd.DataFrame()
xgb_result_metrics_df['batch_id'] = xgb_batch_id_array_result
xgb_result_metrics_df['mae_train'] = xgb_batch_mae_train_array
xgb_result_metrics_df['rmse_train'] = xgb_batch_rmse_train_array
xgb_result_metrics_df['mae_test'] = xgb_batch_mae_test_array
xgb_result_metrics_df['rmse_test'] = xgb_batch_rmse_test_array
# Out:
# 100%|██████████| 27/27 [00:05<00:00,  4.84it/s]

# %%
plot_results(xgb_y_test_array,xgb_y_test_pred_array,'results-test')

# %%
xgb_result_metrics_df
# Out:
#     batch_id   mae_train   rmse_train      mae_test     rmse_test
# 0          0   13.612726    22.233204     25.011727     34.377692
# 1          1   14.419640    22.666826      5.524304      6.997888
# 2          2    9.339369    14.295005      5.645327      8.038763
# 3          3    5.707667     7.887201     30.232814     39.655701
# 4          4    5.288323     7.410367      8.154196     11.475054
# 5          5    4.778483     6.684793    121.304642    159.803284
# 6          6    4.914978     7.181662     30.738365     38.220545
# 7          7    5.619313     8.260718    180.367825    213.653188
# 8          8    7.304489    10.916484    324.709283    392.459296
# 9          9   10.634145    17.173958   1123.292979   1291.138301
# 10        10   22.843137    38.822526   1772.779549   2535.305802
# 11        11   47.376983    82.106140   2516.755332   3334.313264
# 12        12  122.751985   231.712779    362.897686    459.055509
# 13        13  165.044869   269.080870    188.829229    247.611578
# 14        14  184.816887   277.598241    679.499543    905.303082
# 15        15  190.612976   276.264547    109.036450    162.200493
# 16        16  161.600390   258.406432    982.942158   1148.624689
# 17        17  120.363566   177.235994    665.936767    742.555215
# 18        18  119.662703   176.688632    301.589309    361.686445
# 19        19  122.594650   182.080830    419.228890    569.438067
# 20        20  142.126186   221.039603    427.735553    608.539629
# 21        21  166.098484   241.085987   2792.891193   3932.300824
# 22        22  163.177687   243.601438  20156.699012  23390.208671
# 23        23  266.342822   462.678105   4867.174508   5934.715666
# 24        24  518.667520   876.024863   1581.612492   2117.512176
# 25        25  684.175583  1054.106003   5622.207828   6781.867160
# 26        26  887.666715  1273.780079   1353.527713   1839.017509

# %%
pd.DataFrame(xgb_result_metrics_df.mean()).drop(['batch_id'],axis=0)
# Out:
#                       0
# mae_train    154.353418
# rmse_train   239.519381
# mae_test    1728.012025
# rmse_test   2120.965759

# %%
xgb_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/xgb_result_test_20210922.csv')
xgb_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/xgb_result_metrics_20210922.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19224/3658883689.py in <module>
# ----> 1 xgb_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/xgb_result_test_20210922.csv')
#       2 xgb_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/xgb_result_metrics_20210922.csv')
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/xgb_result_test_20210922.csv'

# %% [markdown]
# ## Linear Regression

# %%
lr_date_array = []
lr_y_test_array = []
lr_y_test_pred_array = []
lr_batch_id_array = []
lr_batch_id_array_result = []
lr_batch_mae_train_array = []
lr_batch_rmse_train_array = []
lr_batch_mae_test_array = []
lr_batch_rmse_test_array = []

for i in tqdm(range(len(train_splits))):
    Xtrain_split = train_splits[i].drop(['next_day_closing_price','Date'],axis=1)
    Xtest_split = test_splits[i].drop(['next_day_closing_price','Date'],axis=1)
    ytrain_split = train_splits[i]['next_day_closing_price'].reset_index(drop=True).values
    ytest_split = test_splits[i]['next_day_closing_price'].reset_index(drop=True).values

    sgd_reg = SGDRegressor(loss='squared_epsilon_insensitive',alpha=0.0001,penalty='elasticnet',shuffle=True,
                           tol=0.000001,l1_ratio=0.15,epsilon=0.01,learning_rate='adaptive',max_iter=1000,eta0 =0.01)
    sgd_reg.fit(Xtrain_split, ytrain_split)

    #pickle.dump(sgd_reg, open(f'/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/Linear Regression Model/linear_reg_10_{i}.sav', 'wb'))

    ytrain_pred = sgd_reg.predict(Xtrain_split)
    ytest_pred = sgd_reg.predict(Xtest_split)

    MAE_train,RMSE_train = calculate_metrics(ytrain_split,ytrain_pred)
    MAE_test,RMSE_test = calculate_metrics(ytest_split,ytest_pred)

    lr_date_array.extend(test_splits[i]['Date'])
    lr_y_test_array.extend(test_splits[i]['next_day_closing_price'])
    lr_y_test_pred_array.extend((ytest_pred.flatten()))
    lr_batch_id_array.extend([i]*len(test_splits[i]))

    lr_batch_id_array_result.append(i)
    lr_batch_mae_train_array.append(MAE_train)
    lr_batch_rmse_train_array.append(RMSE_train)
    lr_batch_mae_test_array.append(MAE_test)
    lr_batch_rmse_test_array.append(RMSE_test)

lr_result_test_df = pd.DataFrame()
lr_result_test_df['batch_id'] = lr_batch_id_array
lr_result_test_df['Date'] = lr_date_array
lr_result_test_df['y_test'] = lr_y_test_array
lr_result_test_df['y_test_pred'] = lr_y_test_pred_array
lr_y_test_array = lr_result_test_df['y_test']
lr_y_test_pred_array = lr_result_test_df['y_test_pred']

lr_result_metrics_df = pd.DataFrame()
lr_result_metrics_df['batch_id'] = lr_batch_id_array_result
lr_result_metrics_df['mae_train'] = lr_batch_mae_train_array
lr_result_metrics_df['rmse_train'] = lr_batch_rmse_train_array
lr_result_metrics_df['mae_test'] = lr_batch_mae_test_array
lr_result_metrics_df['rmse_test'] = lr_batch_rmse_test_array
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 31.43it/s]

# %%
plot_results(lr_y_test_array,lr_y_test_pred_array,'results-test')

# %%
lr_result_metrics_df
# Out:
#     batch_id    mae_train   rmse_train     mae_test    rmse_test
# 0          0    87.683325   130.225374    31.891411    41.872881
# 1          1   111.157627   151.175974    24.640062    26.709025
# 2          2    69.773841    94.934107    42.532494    46.993896
# 3          3    59.223900    72.309495    71.887484    89.370103
# 4          4    53.074603    67.118669    87.552759    91.316616
# 5          5    38.390791    51.544960   179.828619   210.384219
# 6          6    43.303511    54.894510    59.825539    64.022654
# 7          7    44.238315    54.240096   168.256387   188.015302
# 8          8    51.282884    68.839881   123.115320   178.050768
# 9          9    69.779924    97.761011  1287.348510  1408.456395
# 10        10   105.983431   155.393819   652.932312   828.287577
# 11        11   162.444158   249.968143  1524.873757  1954.549741
# 12        12   257.078239   504.082734   623.782011   713.142220
# 13        13   317.040882   532.674999   261.076577   333.919571
# 14        14   340.350658   546.788867   458.368111   502.628313
# 15        15   350.074207   550.294958   157.734332   193.571489
# 16        16   307.633915   537.706430   396.963345   541.258738
# 17        17   232.683723   335.800293   324.972974   416.893929
# 18        18   219.877026   333.217374   334.912900   381.535778
# 19        19   222.778118   334.885743   427.463782   608.376481
# 20        20   259.081858   396.054289   171.524274   248.596046
# 21        21   262.745624   395.693541   452.218434   628.346290
# 22        22   257.850270   390.880498  1722.779218  2239.460173
# 23        23   552.370994  1015.092226  4069.426004  4874.860748
# 24        24   843.347996  1418.580033  1359.452620  1776.614870
# 25        25  1035.025400  1572.597652  1521.259172  1970.156104
# 26        26  1301.473340  1797.705557  1235.547432  1711.931042

# %%
pd.DataFrame(lr_result_metrics_df.mean()).drop(['batch_id'],axis=0)
# Out:
#                      0
# mae_train   283.546243
# rmse_train  441.128194
# mae_test    658.228364
# rmse_test   824.789665

# %%
lr_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lr_result_test_20210922.csv')
lr_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lr_result_metrics_20210922.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12208/3346768342.py in <module>
# ----> 1 lr_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lr_result_test_20210922.csv')
#       2 lr_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lr_result_metrics_20210922.csv')
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lr_result_test_20210922.csv'

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Callbacks

# %% [markdown]
# #### EarlyStopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
earlystop=EarlyStopping(monitor='root_mean_squared_error',min_delta=1e-3,patience=50,verbose=100,mode='min')

# %% [markdown]
# ####  Learning Rate Scheduler

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
def changeLearningRate(epoch,lr):
    if (epoch+1) == 1:
        lr = 0.001
    if (epoch+1)%5==0:
        return lr*0.98
    else:
        return lr

lrschedule=LearningRateScheduler(changeLearningRate, verbose=1)

# %%
reduce_lr=ReduceLROnPlateau(monitor='root_mean_squared_error', factor=0.98,patience=3,verbose=1,mode='min')

# %%
callback_list=[reduce_lr,lrschedule,earlystop]

# %% [markdown]
# ### Build Model

# %%
input_layer = Input(shape=(1, 16),name='input_layer')
lstm_1 = LSTM(400, return_sequences=True,activation='relu',name='lstm_1')(input_layer)
dropout_1 = Dropout(0.25,name='dropout_1')(lstm_1)
lstm_2 = LSTM(500, return_sequences=True,activation='relu',name='lstm_2')(dropout_1)
dropout_2 = Dropout(0.3,name='dropout_2')(lstm_2)
output_layer = Dense(1,name='output_layer')(dropout_2)

model=Model(inputs=input_layer,outputs=output_layer)
adam=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-07)
model.compile(optimizer=adam, loss='log_cosh',metrics=[tf.keras.metrics.RootMeanSquaredError(),'mae'])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 16)]           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 400)            667200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 400)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 500)            1802000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 500)            0
# _________________________________________________________________
# output_layer (Dense)         (None, 1, 1)              501
# =================================================================
# Total params: 2,469,701
# Trainable params: 2,469,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
# path = '/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/Model Train10'
# if not os.path.exists(path):
#     os.makedirs(path)
# if not os.path.exists(f'{path}/pickled_arrays'):
#     os.makedirs(f'{path}/pickled_arrays')

# %%
lstm_date_array = []
lstm_y_test_array = []
lstm_y_test_pred_array = []
lstm_batch_id_array = []
lstm_batch_id_array_result = []
lstm_batch_mae_train_array = []
lstm_batch_rmse_train_array = []
lstm_batch_mae_test_array = []
lstm_batch_rmse_test_array = []

for i in range(len(train_splits)):
    print(f'Batch No. {i+1} of {len(train_splits)}')
    print('Train Data From',train_splits[i]['Date'].iloc[0],'-',train_splits[i]['next_day_closing_price'].min(),
          'to',train_splits[i]['Date'].iloc[-1],'-',train_splits[i]['next_day_closing_price'].max())
    
    print('Test Data From',test_splits[i]['Date'].iloc[0],'-',test_splits[i]['next_day_closing_price'].min(),
          'to',test_splits[i]['Date'].iloc[-1],'-',test_splits[i]['next_day_closing_price'].max())
    
    del model
    K.clear_session()
    tf.compat.v1.reset_default_graph()

    model=Model(inputs=input_layer,outputs=output_layer)
    model.compile(optimizer=adam, loss='Huber',metrics=[tf.keras.metrics.RootMeanSquaredError(),'mae'])
    Xtrain_split = train_splits[i].drop(['next_day_closing_price','Date'],axis=1).values
    Xtest_split = test_splits[i].drop(['next_day_closing_price','Date'],axis=1).values

    ytrain_split = train_splits[i]['next_day_closing_price'].reset_index(drop=True).values
    ytest_split = test_splits[i]['next_day_closing_price'].reset_index(drop=True).values

    Xtrain_split=np.reshape(Xtrain_split,(Xtrain_split.shape[0],1,Xtrain_split.shape[1]))
    Xtest_split=np.reshape(Xtest_split,(Xtest_split.shape[0],1,Xtest_split.shape[1]))

    model.fit(Xtrain_split,ytrain_split,epochs=500,batch_size=32,verbose=2,
              callbacks = [reduce_lr,lrschedule,earlystop])
    #model.save(f'/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/LSTM/lstm_{i+1}')
    ytrain_pred = model.predict(Xtrain_split).reshape(-1,1)
    ytest_pred = model.predict(Xtest_split).reshape(-1,1)
    
    MAE_train,RMSE_train = calculate_metrics(ytrain_split,ytrain_pred)
    MAE_test,RMSE_test = calculate_metrics(ytest_split,ytest_pred)

    lstm_date_array.extend(test_splits[i]['Date'])
    lstm_y_test_array.extend(test_splits[i]['next_day_closing_price'])
    lstm_y_test_pred_array.extend((ytest_pred.flatten()))
    lstm_batch_id_array.extend([i]*len(test_splits[i]))

    lstm_batch_id_array_result.append(i)
    lstm_batch_mae_train_array.append(MAE_train)
    lstm_batch_rmse_train_array.append(RMSE_train)
    lstm_batch_mae_test_array.append(MAE_test)
    lstm_batch_rmse_test_array.append(RMSE_test)
    print('*'*100)

lstm_result_test_df = pd.DataFrame()
lstm_result_test_df['batch_id'] = lstm_batch_id_array
lstm_result_test_df['Date'] = lstm_date_array
lstm_result_test_df['y_test'] = lstm_y_test_array
lstm_result_test_df['y_test_pred'] = lstm_y_test_pred_array
lstm_y_test_array = lstm_result_test_df['y_test']
lstm_y_test_pred_array = lstm_result_test_df['y_test_pred']
lstm_result_metrics_df = pd.DataFrame()
lstm_result_metrics_df['batch_id'] = lstm_batch_id_array_result
lstm_result_metrics_df['mae_train'] = lstm_batch_mae_train_array
lstm_result_metrics_df['rmse_train'] = lstm_batch_rmse_train_array
lstm_result_metrics_df['mae_test'] = lstm_batch_mae_test_array
lstm_result_metrics_df['rmse_test'] = lstm_batch_rmse_test_array
# Out:
# Batch No. 1 of 27
# Train Data From 2013-07-17 - 89.8 to 2014-11-28 - 1237.6
# Test Data From 2014-11-29 - 164.9 to 2015-03-08 - 380.6
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/500
# 16/16 - 0s - loss: 474.6957 - root_mean_squared_error: 538.6503 - mae: 475.1957
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/500
# 16/16 - 0s - loss: 474.4159 - root_mean_squared_error: 538.3938 - mae: 474.9159
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/500
# 16/16 - 0s - loss: 473.4785 - root_mean_squared_error: 537.5311 - mae: 473.9785
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/500
# 16/16 - 0s - loss: 470.5601 - root_mean_squared_error: 534.8658 - mae: 471.0601
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009800000465475024.
# Epoch 5/500
# 16/16 - 0s - loss: 462.0375 - root_mean_squared_error: 526.9752 - mae: 462.5375
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 6/500
# 16/16 - 0s - loss: 439.2705 - root_mean_squared_error: 506.3777 - mae: 439.7705
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 7/500
# 16/16 - 0s - loss: 387.3273 - root_mean_squared_error: 459.7893 - mae: 387.8257
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 8/500
# 16/16 - 0s - loss: 305.4599 - root_mean_squared_error: 383.8141 - mae: 305.9588
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 9/500
# 16/16 - 0s - loss: 224.1173 - root_mean_squared_error: 297.7282 - mae: 224.6173
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009604000113904476.
# Epoch 10/500
# 16/16 - 0s - loss: 178.0161 - root_mean_squared_error: 236.4458 - mae: 178.5159
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 11/500
# 16/16 - 0s - loss: 170.8797 - root_mean_squared_error: 220.7315 - mae: 171.3792
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 12/500
# 16/16 - 0s - loss: 170.2313 - root_mean_squared_error: 221.8455 - mae: 170.7306
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 13/500
# 16/16 - 0s - loss: 166.8298 - root_mean_squared_error: 218.6114 - mae: 167.3286
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 14/500
# 16/16 - 0s - loss: 166.6279 - root_mean_squared_error: 218.2804 - mae: 167.1278
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0009411920362617821.
# Epoch 15/500
# 16/16 - 0s - loss: 163.4745 - root_mean_squared_error: 216.9275 - mae: 163.9745
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009411920327693224.
# Epoch 16/500
# 16/16 - 0s - loss: 160.5246 - root_mean_squared_error: 214.2872 - mae: 161.0243
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0009411920327693224.
# Epoch 17/500
# 16/16 - 0s - loss: 161.4306 - root_mean_squared_error: 215.1444 - mae: 161.9305
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009411920327693224.
# Epoch 18/500
# 16/16 - 0s - loss: 158.6729 - root_mean_squared_error: 210.6414 - mae: 159.1729
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0009411920327693224.
# Epoch 19/500
# 16/16 - 0s - loss: 156.9272 - root_mean_squared_error: 210.3781 - mae: 157.4264
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 0.00040287784475367516.
# Epoch 150/500
# 16/16 - 0s - loss: 50.4040 - root_mean_squared_error: 79.6392 - mae: 50.9013
#
# Epoch 00151: LearningRateScheduler reducing learning rate to 0.0004028778348583728.
# Epoch 151/500
#
# Epoch 00151: ReduceLROnPlateau reducing learning rate to 0.0003948202781612053.
# 16/16 - 0s - loss: 49.4993 - root_mean_squared_error: 77.8387 - mae: 49.9957
#
# Epoch 00152: LearningRateScheduler reducing learning rate to 0.00039482026477344334.
# Epoch 152/500
# 16/16 - 0s - loss: 48.2990 - root_mean_squared_error: 78.8790 - mae: 48.7960
#
# Epoch 00153: LearningRateScheduler reducing learning rate to 0.00039482026477344334.
# Epoch 153/500
# 16/16 - 0s - loss: 49.6834 - root_mean_squared_error: 79.9221 - mae: 50.1796
#
# Epoch 00154: LearningRateScheduler reducing learning rate to 0.00039482026477344334.
# Epoch 154/500
#
# Epoch 00154: ReduceLROnPlateau reducing learning rate to 0.0003869238594779745.
# 16/16 - 0s - loss: 49.9055 - root_mean_squared_error: 78.4311 - mae: 50.3999
#
# Epoch 00155: LearningRateScheduler reducing learning rate to 0.0003791853942675516.
# Epoch 155/500
# 16/16 - 0s - loss: 50.0132 - root_mean_squared_error: 80.2104 - mae: 50.5110
#
# Epoch 00156: LearningRateScheduler reducing learning rate to 0.00037918539601378143.
# Epoch 156/500
# 16/16 - 0s - loss: 49.6164 - root_mean_squared_error: 80.9860 - mae: 50.1103
#
# Epoch 00157: LearningRateScheduler reducing learning rate to 0.00037918539601378143.
# Epoch 157/500
#
# Epoch 00157: ReduceLROnPlateau reducing learning rate to 0.0003716016880935058.
# 16/16 - 0s - loss: 50.3569 - root_mean_squared_error: 80.6987 - mae: 50.8539
#
# Epoch 00158: LearningRateScheduler reducing learning rate to 0.0003716016944963485.
# Epoch 158/500
# 16/16 - 0s - loss: 48.6920 - root_mean_squared_error: 77.2797 - mae: 49.1883
#
# Epoch 00159: LearningRateScheduler reducing learning rate to 0.0003716016944963485.
# Epoch 159/500
# 16/16 - 0s - loss: 49.6988 - root_mean_squared_error: 79.4082 - mae: 50.1973
#
# Epoch 00160: LearningRateScheduler reducing learning rate to 0.0003641696606064215.
# Epoch 160/500
#
# Epoch 00160: ReduceLROnPlateau reducing learning rate to 0.0003568862599786371.
# 16/16 - 0s - loss: 50.1351 - root_mean_squared_error: 77.4400 - mae: 50.6319
#
# Epoch 00161: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 161/500
# 16/16 - 0s - loss: 50.3149 - root_mean_squared_error: 83.2546 - mae: 50.8112
#
# Epoch 00162: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 162/500
# 16/16 - 0s - loss: 48.7670 - root_mean_squared_error: 76.7285 - mae: 49.2635
#
# Epoch 00163: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 163/500
# 16/16 - 0s - loss: 51.0758 - root_mean_squared_error: 83.4861 - mae: 51.5714
#
# Epoch 00164: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 164/500
# 16/16 - 0s - loss: 50.7574 - root_mean_squared_error: 80.1823 - mae: 51.2533
#
# Epoch 00165: LearningRateScheduler reducing learning rate to 0.0003497485484695062.
# Epoch 165/500
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 0.0003427535883383825.
# 16/16 - 0s - loss: 49.1698 - root_mean_squared_error: 79.7748 - mae: 49.6638
#
# Epoch 00166: LearningRateScheduler reducing learning rate to 0.0003427535993978381.
# Epoch 166/500
# 16/16 - 0s - loss: 48.0930 - root_mean_squared_error: 78.5893 - mae: 48.5897
#
# Epoch 00167: LearningRateScheduler reducing learning rate to 0.0003427535993978381.
# Epoch 167/500
# 16/16 - 0s - loss: 51.7508 - root_mean_squared_error: 81.3575 - mae: 52.2454
#
# Epoch 00168: LearningRateScheduler reducing learning rate to 0.0003427535993978381.
# Epoch 168/500
#
# Epoch 00168: ReduceLROnPlateau reducing learning rate to 0.00033589852740988134.
# 16/16 - 0s - loss: 48.2174 - root_mean_squared_error: 79.7548 - mae: 48.7131
#
# Epoch 00169: LearningRateScheduler reducing learning rate to 0.00033589854137971997.
# Epoch 169/500
# 16/16 - 0s - loss: 49.0458 - root_mean_squared_error: 78.4412 - mae: 49.5427
#
# Epoch 00170: LearningRateScheduler reducing learning rate to 0.00032918057055212555.
# Epoch 170/500
# 16/16 - 0s - loss: 49.3103 - root_mean_squared_error: 78.6547 - mae: 49.8077
#
# Epoch 00171: LearningRateScheduler reducing learning rate to 0.00032918056240305305.
# Epoch 171/500
#
# Epoch 00171: ReduceLROnPlateau reducing learning rate to 0.000322596951154992.
# 16/16 - 0s - loss: 50.5799 - root_mean_squared_error: 81.2318 - mae: 51.0773
#
# Epoch 00172: LearningRateScheduler reducing learning rate to 0.00032259695581160486.
# Epoch 172/500
# 16/16 - 0s - loss: 49.3457 - root_mean_squared_error: 78.7946 - mae: 49.8420
#
# Epoch 00173: LearningRateScheduler reducing learning rate to 0.00032259695581160486.
# Epoch 173/500
# 16/16 - 0s - loss: 51.1443 - root_mean_squared_error: 79.8775 - mae: 51.6392
#
# Epoch 00174: LearningRateScheduler reducing learning rate to 0.00032259695581160486.
# Epoch 174/500
#
# Epoch 00174: ReduceLROnPlateau reducing learning rate to 0.0003161450166953728.
# 16/16 - 0s - loss: 49.2695 - root_mean_squared_error: 77.8491 - mae: 49.7632
#
# Epoch 00175: LearningRateScheduler reducing learning rate to 0.00030982211465016004.
# Epoch 175/500
# 16/16 - 0s - loss: 51.6580 - root_mean_squared_error: 83.2498 - mae: 52.1557
# Epoch 00176: LearningRateScheduler reducing learning rate to 0.00030982212047092617.
# Epoch 176/500
# 16/16 - 0s - loss: 50.2889 - root_mean_squared_error: 80.0767 - mae: 50.7870
#
# Epoch 00177: LearningRateScheduler reducing learning rate to 0.00030982212047092617.
# Epoch 177/500
#
# Epoch 00177: ReduceLROnPlateau reducing learning rate to 0.0003036256780615076.
# 16/16 - 0s - loss: 50.3046 - root_mean_squared_error: 76.8349 - mae: 50.8016
#
# Epoch 00178: LearningRateScheduler reducing learning rate to 0.0003036256821360439.
# Epoch 178/500
# 16/16 - 0s - loss: 49.5324 - root_mean_squared_error: 78.6708 - mae: 50.0303
#
# Epoch 00179: LearningRateScheduler reducing learning rate to 0.0003036256821360439.
# Epoch 179/500
# 16/16 - 0s - loss: 50.6472 - root_mean_squared_error: 77.8317 - mae: 51.1453
#
# Epoch 00180: LearningRateScheduler reducing learning rate to 0.000297553168493323.
# Epoch 180/500
#
# Epoch 00180: ReduceLROnPlateau reducing learning rate to 0.0002916021045530215.
# 16/16 - 0s - loss: 49.7452 - root_mean_squared_error: 80.6401 - mae: 50.2430
#
# Epoch 00181: LearningRateScheduler reducing learning rate to 0.0002916021039709449.
# Epoch 181/500
# 16/16 - 0s - loss: 49.3053 - root_mean_squared_error: 78.2487 - mae: 49.8024
#
# Epoch 00182: LearningRateScheduler reducing learning rate to 0.0002916021039709449.
# Epoch 182/500
# 16/16 - 0s - loss: 50.9123 - root_mean_squared_error: 78.7252 - mae: 51.4109
#
# Epoch 00183: LearningRateScheduler reducing learning rate to 0.0002916021039709449.
# Epoch 183/500
# 16/16 - 0s - loss: 47.0696 - root_mean_squared_error: 76.0756 - mae: 47.5670
#
# Epoch 00184: LearningRateScheduler reducing learning rate to 0.0002916021039709449.
# Epoch 184/500
# 16/16 - 0s - loss: 49.0687 - root_mean_squared_error: 79.8148 - mae: 49.5641
#
# Epoch 00185: LearningRateScheduler reducing learning rate to 0.000285770061891526.
# Epoch 185/500
# 16/16 - 0s - loss: 46.3740 - root_mean_squared_error: 74.0793 - mae: 46.8699
#
# Epoch 00186: LearningRateScheduler reducing learning rate to 0.0002857700746972114.
# Epoch 186/500
# 16/16 - 0s - loss: 50.0329 - root_mean_squared_error: 79.5424 - mae: 50.5288
#
# Epoch 00187: LearningRateScheduler reducing learning rate to 0.0002857700746972114.
# Epoch 187/500
# 16/16 - 0s - loss: 49.5658 - root_mean_squared_error: 76.7609 - mae: 50.0624
#
# Epoch 00188: LearningRateScheduler reducing learning rate to 0.0002857700746972114.
# Epoch 188/500
#
# Epoch 00188: ReduceLROnPlateau reducing learning rate to 0.0002800546732032672.
# 16/16 - 0s - loss: 48.6227 - root_mean_squared_error: 77.7385 - mae: 49.1200
#
# Epoch 00189: LearningRateScheduler reducing learning rate to 0.000280054664472118.
# Epoch 189/500
# 16/16 - 0s - loss: 49.3719 - root_mean_squared_error: 79.4088 - mae: 49.8694
#
# Epoch 00190: LearningRateScheduler reducing learning rate to 0.00027445357118267567.
# Epoch 190/500
# 16/16 - 0s - loss: 50.4321 - root_mean_squared_error: 79.2627 - mae: 50.9267
#
# Epoch 00191: LearningRateScheduler reducing learning rate to 0.0002744535740930587.
# Epoch 191/500
#
# Epoch 00191: ReduceLROnPlateau reducing learning rate to 0.0002689645026111975.
# 16/16 - 0s - loss: 48.8163 - root_mean_squared_error: 77.9172 - mae: 49.3148
#
# Epoch 00192: LearningRateScheduler reducing learning rate to 0.00026896450435742736.
# Epoch 192/500
# 16/16 - 0s - loss: 49.9763 - root_mean_squared_error: 78.1448 - mae: 50.4723
#
# Epoch 00193: LearningRateScheduler reducing learning rate to 0.00026896450435742736.
# Epoch 193/500
# 16/16 - 0s - loss: 46.6325 - root_mean_squared_error: 74.7477 - mae: 47.1316
#
# Epoch 00194: LearningRateScheduler reducing learning rate to 0.00026896450435742736.
# Epoch 194/500
#
# Epoch 00194: ReduceLROnPlateau reducing learning rate to 0.0002635852142702788.
# 16/16 - 0s - loss: 51.9724 - root_mean_squared_error: 81.1315 - mae: 52.4693
#
# Epoch 00195: LearningRateScheduler reducing learning rate to 0.0002583135099848732.
# Epoch 195/500
# 16/16 - 0s - loss: 49.1728 - root_mean_squared_error: 77.7889 - mae: 49.6687
#
# Epoch 00196: LearningRateScheduler reducing learning rate to 0.0002583135210443288.
# Epoch 196/500
# 16/16 - 0s - loss: 48.8218 - root_mean_squared_error: 76.6058 - mae: 49.3183
#
# Epoch 00197: LearningRateScheduler reducing learning rate to 0.0002583135210443288.
# Epoch 197/500
#
# Epoch 00197: ReduceLROnPlateau reducing learning rate to 0.00025314725062344225.
# 16/16 - 0s - loss: 48.8357 - root_mean_squared_error: 77.2696 - mae: 49.3341
#
# Epoch 00198: LearningRateScheduler reducing learning rate to 0.0002531472418922931.
# Epoch 198/500
# 16/16 - 0s - loss: 49.4214 - root_mean_squared_error: 77.3994 - mae: 49.9179
#
# Epoch 00199: LearningRateScheduler reducing learning rate to 0.0002531472418922931.
# Epoch 199/500
# 16/16 - 0s - loss: 47.9403 - root_mean_squared_error: 77.4785 - mae: 48.4367
#
# Epoch 00200: LearningRateScheduler reducing learning rate to 0.0002480842970544472.
# Epoch 200/500
#
# Epoch 00200: ReduceLROnPlateau reducing learning rate to 0.00024312262423336505.
# 16/16 - 0s - loss: 48.1817 - root_mean_squared_error: 75.2976 - mae: 48.6796
#
# Epoch 00201: LearningRateScheduler reducing learning rate to 0.00024312263121828437.
# Epoch 201/500
# 16/16 - 0s - loss: 48.5114 - root_mean_squared_error: 76.9390 - mae: 49.0073
#
# Epoch 00202: LearningRateScheduler reducing learning rate to 0.00024312263121828437.
# Epoch 202/500
# 16/16 - 0s - loss: 49.0439 - root_mean_squared_error: 78.1166 - mae: 49.5426
#
# Epoch 00203: LearningRateScheduler reducing learning rate to 0.00024312263121828437.
# Epoch 203/500
#
# Epoch 00203: ReduceLROnPlateau reducing learning rate to 0.00023826017859391866.
# 16/16 - 0s - loss: 49.7648 - root_mean_squared_error: 77.4973 - mae: 50.2625
#
# Epoch 00204: LearningRateScheduler reducing learning rate to 0.00023826018150430173.
# Epoch 204/500
# 16/16 - 0s - loss: 49.3824 - root_mean_squared_error: 76.4535 - mae: 49.8784
#
# Epoch 00205: LearningRateScheduler reducing learning rate to 0.00023349497787421568.
# Epoch 205/500
# 16/16 - 0s - loss: 48.8497 - root_mean_squared_error: 78.2824 - mae: 49.3456
#
# Epoch 00206: LearningRateScheduler reducing learning rate to 0.00023349498223979026.
# Epoch 206/500
#
# Epoch 00206: ReduceLROnPlateau reducing learning rate to 0.00022882508259499445.
# 16/16 - 0s - loss: 47.7884 - root_mean_squared_error: 75.7971 - mae: 48.2855
#
# Epoch 00207: LearningRateScheduler reducing learning rate to 0.00022882508346810937.
# Epoch 207/500
# 16/16 - 0s - loss: 50.2815 - root_mean_squared_error: 80.8699 - mae: 50.7805
#
# Epoch 00208: LearningRateScheduler reducing learning rate to 0.00022882508346810937.
# Epoch 208/500
# 16/16 - 0s - loss: 48.0594 - root_mean_squared_error: 77.9319 - mae: 48.5570
#
# Epoch 00209: LearningRateScheduler reducing learning rate to 0.00022882508346810937.
# Epoch 209/500
# 16/16 - 0s - loss: 46.7693 - root_mean_squared_error: 73.1717 - mae: 47.2644
#
# Epoch 00210: LearningRateScheduler reducing learning rate to 0.00022424858179874717.
# Epoch 210/500
# 16/16 - 0s - loss: 47.8153 - root_mean_squared_error: 75.4739 - mae: 48.3119
#
# Epoch 00211: LearningRateScheduler reducing learning rate to 0.00022424857888836414.
# Epoch 211/500
# 16/16 - 0s - loss: 50.6400 - root_mean_squared_error: 78.6116 - mae: 51.1357
#
# Epoch 00212: LearningRateScheduler reducing learning rate to 0.00022424857888836414.
# Epoch 212/500
#
# Epoch 00212: ReduceLROnPlateau reducing learning rate to 0.00021976360731059685.
# 16/16 - 0s - loss: 48.9547 - root_mean_squared_error: 77.4970 - mae: 49.4518
#
# Epoch 00213: LearningRateScheduler reducing learning rate to 0.00021976360585540533.
# Epoch 213/500
# 16/16 - 0s - loss: 48.5671 - root_mean_squared_error: 75.8155 - mae: 49.0639
#
# Epoch 00214: LearningRateScheduler reducing learning rate to 0.00021976360585540533.
# Epoch 214/500
# 16/16 - 0s - loss: 48.5559 - root_mean_squared_error: 77.6636 - mae: 49.0533
#
# Epoch 00215: LearningRateScheduler reducing learning rate to 0.0002153683337382972.
# Epoch 215/500
#
# Epoch 00215: ReduceLROnPlateau reducing learning rate to 0.0002110609642113559.
# 16/16 - 0s - loss: 47.4893 - root_mean_squared_error: 76.0292 - mae: 47.9829
#
# Epoch 00216: LearningRateScheduler reducing learning rate to 0.0002110609639203176.
# Epoch 216/500
# 16/16 - 0s - loss: 49.5358 - root_mean_squared_error: 77.6634 - mae: 50.0303
#
# Epoch 00217: LearningRateScheduler reducing learning rate to 0.0002110609639203176.
# Epoch 217/500
# 16/16 - 0s - loss: 49.1703 - root_mean_squared_error: 78.2125 - mae: 49.6668
#
# Epoch 00218: LearningRateScheduler reducing learning rate to 0.0002110609639203176.
# Epoch 218/500
#
# Epoch 00218: ReduceLROnPlateau reducing learning rate to 0.00020683974464191123.
# 16/16 - 0s - loss: 49.0642 - root_mean_squared_error: 76.6822 - mae: 49.5605
#
# Epoch 00219: LearningRateScheduler reducing learning rate to 0.00020683974435087293.
# Epoch 219/500
# 16/16 - 0s - loss: 46.8730 - root_mean_squared_error: 75.1511 - mae: 47.3703
#
# Epoch 00220: LearningRateScheduler reducing learning rate to 0.00020270294946385546.
# Epoch 220/500
# 16/16 - 0s - loss: 47.6993 - root_mean_squared_error: 75.0883 - mae: 48.1947
#
# Epoch 00221: LearningRateScheduler reducing learning rate to 0.00020270295499358326.
# Epoch 221/500
#
# Epoch 00221: ReduceLROnPlateau reducing learning rate to 0.0001986488958937116.
# 16/16 - 0s - loss: 47.2416 - root_mean_squared_error: 77.1871 - mae: 47.7388
#
# Epoch 00222: LearningRateScheduler reducing learning rate to 0.00019864889327436686.
# Epoch 222/500
# 16/16 - 0s - loss: 46.6524 - root_mean_squared_error: 74.3944 - mae: 47.1478
#
# Epoch 00223: LearningRateScheduler reducing learning rate to 0.00019864889327436686.
# Epoch 223/500
# 16/16 - 0s - loss: 47.8514 - root_mean_squared_error: 75.7616 - mae: 48.3478
#
# Epoch 00224: LearningRateScheduler reducing learning rate to 0.00019864889327436686.
# Epoch 224/500
#
# Epoch 00224: ReduceLROnPlateau reducing learning rate to 0.0001946759154088795.
# 16/16 - 0s - loss: 50.8086 - root_mean_squared_error: 81.0868 - mae: 51.3044
#
# Epoch 00225: LearningRateScheduler reducing learning rate to 0.00019078239653026684.
# Epoch 225/500
# 16/16 - 0s - loss: 46.5363 - root_mean_squared_error: 73.5429 - mae: 47.0322
#
# Epoch 00226: LearningRateScheduler reducing learning rate to 0.00019078238983638585.
# Epoch 226/500
# 16/16 - 0s - loss: 45.6614 - root_mean_squared_error: 75.6856 - mae: 46.1581
#
# Epoch 00227: LearningRateScheduler reducing learning rate to 0.00019078238983638585.
# Epoch 227/500
#
# Epoch 00227: ReduceLROnPlateau reducing learning rate to 0.00018696674203965812.
# 16/16 - 0s - loss: 50.5752 - root_mean_squared_error: 77.4660 - mae: 51.0695
#
# Epoch 00228: LearningRateScheduler reducing learning rate to 0.000186966746696271.
# Epoch 228/500
# 16/16 - 0s - loss: 45.7481 - root_mean_squared_error: 73.7108 - mae: 46.2449
#
# Epoch 00229: LearningRateScheduler reducing learning rate to 0.000186966746696271.
# Epoch 229/500
# 16/16 - 0s - loss: 46.7389 - root_mean_squared_error: 73.5637 - mae: 47.2375
#
# Epoch 00230: LearningRateScheduler reducing learning rate to 0.00018322741176234557.
# Epoch 230/500
#
# Epoch 00230: ReduceLROnPlateau reducing learning rate to 0.00017956286552362144.
# 16/16 - 0s - loss: 47.1717 - root_mean_squared_error: 75.8060 - mae: 47.6665
#
# Epoch 00231: LearningRateScheduler reducing learning rate to 0.000179562863195315.
# Epoch 231/500
# 16/16 - 0s - loss: 48.1192 - root_mean_squared_error: 76.8879 - mae: 48.6152
#
# Epoch 00232: LearningRateScheduler reducing learning rate to 0.000179562863195315.
# Epoch 232/500
# 16/16 - 0s - loss: 48.1920 - root_mean_squared_error: 77.5347 - mae: 48.6847
#
# Epoch 00233: LearningRateScheduler reducing learning rate to 0.000179562863195315.
# Epoch 233/500
#
# Epoch 00233: ReduceLROnPlateau reducing learning rate to 0.0001759716059314087.
# 16/16 - 0s - loss: 47.5234 - root_mean_squared_error: 74.2297 - mae: 48.0182
#
# Epoch 00234: LearningRateScheduler reducing learning rate to 0.00017597161058802158.
# Epoch 234/500
# 16/16 - 0s - loss: 48.9241 - root_mean_squared_error: 77.2250 - mae: 49.4191
#
# Epoch 00235: LearningRateScheduler reducing learning rate to 0.00017245217837626113.
# Epoch 235/500
# 16/16 - 0s - loss: 46.0914 - root_mean_squared_error: 74.0628 - mae: 46.5830
#
# Epoch 00236: LearningRateScheduler reducing learning rate to 0.00017245217168238014.
# Epoch 236/500
#
# Epoch 00236: ReduceLROnPlateau reducing learning rate to 0.00016900312824873252.
# 16/16 - 0s - loss: 47.6998 - root_mean_squared_error: 74.5368 - mae: 48.1987
#
# Epoch 00237: LearningRateScheduler reducing learning rate to 0.00016900313494261354.
# Epoch 237/500
# 16/16 - 0s - loss: 48.0426 - root_mean_squared_error: 76.4586 - mae: 48.5403
#
# Epoch 00238: LearningRateScheduler reducing learning rate to 0.00016900313494261354.
# Epoch 238/500
# 16/16 - 0s - loss: 48.2465 - root_mean_squared_error: 76.3423 - mae: 48.7427
#
# Epoch 00239: LearningRateScheduler reducing learning rate to 0.00016900313494261354.
# Epoch 239/500
#
# Epoch 00239: ReduceLROnPlateau reducing learning rate to 0.00016562307224376126.
# 16/16 - 0s - loss: 45.3600 - root_mean_squared_error: 74.9010 - mae: 45.8570
#
# Epoch 00240: LearningRateScheduler reducing learning rate to 0.0001623106127954088.
# Epoch 240/500
# 16/16 - 0s - loss: 49.0848 - root_mean_squared_error: 77.6017 - mae: 49.5818
#
# Epoch 00241: LearningRateScheduler reducing learning rate to 0.00016231060726568103.
# Epoch 241/500
# 16/16 - 0s - loss: 47.0532 - root_mean_squared_error: 75.4607 - mae: 47.5501
#
# Epoch 00242: LearningRateScheduler reducing learning rate to 0.00016231060726568103.
# Epoch 242/500
#
# Epoch 00242: ReduceLROnPlateau reducing learning rate to 0.0001590643951203674.
# 16/16 - 0s - loss: 47.9571 - root_mean_squared_error: 75.3588 - mae: 48.4552
#
# Epoch 00243: LearningRateScheduler reducing learning rate to 0.0001590643951203674.
# Epoch 243/500
# 16/16 - 0s - loss: 48.5299 - root_mean_squared_error: 76.6256 - mae: 49.0233
#
# Epoch 00244: LearningRateScheduler reducing learning rate to 0.0001590643951203674.
# Epoch 244/500
# 16/16 - 0s - loss: 48.7753 - root_mean_squared_error: 77.7260 - mae: 49.2731
#
# Epoch 00245: LearningRateScheduler reducing learning rate to 0.00015588310721796007.
# Epoch 245/500
# 16/16 - 0s - loss: 46.4618 - root_mean_squared_error: 73.1465 - mae: 46.9538
#
# Epoch 00246: LearningRateScheduler reducing learning rate to 0.00015588311362080276.
# Epoch 246/500
# 16/16 - 0s - loss: 47.2782 - root_mean_squared_error: 74.6157 - mae: 47.7724
#
# Epoch 00247: LearningRateScheduler reducing learning rate to 0.00015588311362080276.
# Epoch 247/500
# 16/16 - 0s - loss: 49.4018 - root_mean_squared_error: 77.2298 - mae: 49.8996
#
# Epoch 00248: LearningRateScheduler reducing learning rate to 0.00015588311362080276.
# Epoch 248/500
#
# Epoch 00248: ReduceLROnPlateau reducing learning rate to 0.0001527654513483867.
# 16/16 - 0s - loss: 47.9822 - root_mean_squared_error: 75.0066 - mae: 48.4785
#
# Epoch 00249: LearningRateScheduler reducing learning rate to 0.00015276545309461653.
# Epoch 249/500
# 16/16 - 0s - loss: 44.0183 - root_mean_squared_error: 71.3340 - mae: 44.5132
#
# Epoch 00250: LearningRateScheduler reducing learning rate to 0.0001497101440327242.
# Epoch 250/500
# 16/16 - 0s - loss: 47.1005 - root_mean_squared_error: 75.1711 - mae: 47.5963
#
# Epoch 00251: LearningRateScheduler reducing learning rate to 0.00014971014752518386.
# Epoch 251/500
# 16/16 - 0s - loss: 48.1234 - root_mean_squared_error: 75.8881 - mae: 48.6179
#
# ...
# Epoch 12/500
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0009223681921139359.
# 16/16 - 0s - loss: 2231.4214 - root_mean_squared_error: 3010.4119 - mae: 2231.9214
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009223681990988553.
# Epoch 13/500
# 16/16 - 0s - loss: 2315.4624 - root_mean_squared_error: 3104.7258 - mae: 2315.9624
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009223681990988553.
# Epoch 14/500
# 16/16 - 0s - loss: 2295.3079 - root_mean_squared_error: 3134.3579 - mae: 2295.8079
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0009039208351168781.
# Epoch 15/500
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0008858424355275929.
# 16/16 - 0s - loss: 2223.6663 - root_mean_squared_error: 3026.8572 - mae: 2224.1663
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0008858424262143672.
# Epoch 16/500
# 16/16 - 0s - loss: 2335.3135 - root_mean_squared_error: 3118.3816 - mae: 2335.8132
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0008858424262143672.
# Epoch 17/500
# 16/16 - 0s - loss: 2238.0078 - root_mean_squared_error: 3053.3718 - mae: 2238.5078
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0008858424262143672.
# Epoch 18/500
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.
# Out:
# Pearsons correlation: 0.994

# %%
lstm_result_metrics_df
# Out:
#     batch_id    mae_train   rmse_train     mae_test    rmse_test
# 0          0    37.693500    66.025918    26.831339    29.875097
# 1          1    32.034010    57.590162     7.655215     9.054613
# 2          2    19.616793    38.574984    23.595308    25.631343
# 3          3    11.002762    15.817696    22.314388    28.251619
# 4          4     9.977844    14.672658    43.132805    47.367176
# 5          5     8.425994    12.899318    17.623683    26.808037
# 6          6     9.408072    15.306963     9.052239    16.020813
# 7          7     9.354272    15.877360    21.200766    34.728176
# 8          8    12.683421    21.869508    42.245854    63.867435
# 9          9    18.450386    30.641741   386.779032   490.392679
# 10        10    42.253337    78.736654   801.738635  1137.222460
# 11        11    90.813654   164.664885  1804.819095  2321.856535
# 12        12   238.846375   482.933630   296.776127   391.651460
# 13        13   283.693865   504.573716   212.632918   282.371995
# 14        14   312.767778   515.214716   141.877836   210.066608
# 15        15   312.279433   513.009837    71.538117   115.395799
# 16        16   292.741539   501.677084   378.239496   540.287189
# 17        17   235.806146   341.764605   278.054526   398.135113
# 18        18   203.432703   326.237643   183.585277   236.427444
# 19        19   210.626329   328.354487   344.280305   514.607388
# 20        20   240.119184   381.182010   179.237441   253.549187
# 21        21   265.731833   395.936263   325.856289   493.716875
# 22        22   242.865659   377.042640  2406.796289  3175.070805
# 23        23   520.346692  1025.813092  1806.376297  2289.563631
# 24        24   840.057092  1439.039595  1339.906937  1736.915831
# 25        25  1045.391604  1602.007496  1526.936828  1977.380180
# 26        26  1333.470695  1839.423274  1245.313345  1693.306017

# %%
pd.DataFrame(lstm_result_metrics_df.mean()).drop(['batch_id'])
# Out:
#                      0
# mae_train   254.810777
# rmse_train  411.366220
# mae_test    516.459125
# rmse_test   686.648945

# %%
lstm_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lstm_result_metrics_20210922.csv')
lstm_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lstm_result_test_20210922.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19224/519935757.py in <module>
# ----> 1 lstm_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lstm_result_metrics_20210922.csv')
#       2 lstm_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lstm_result_test_20210922.csv')
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\envs\Bridge\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/lstm_result_metrics_20210922.csv'

# %% [markdown]
# ## BI-LSTM

# %% [markdown]
# ### Callbacks

# %% [markdown]
# #### EarlyStopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
earlystop=EarlyStopping(monitor='root_mean_squared_error',min_delta=1e-3,patience=50,verbose=100,mode='min')

# %% [markdown]
# ####  Learning Rate Scheduler

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
def changeLearningRate(epoch,lr):
    if (epoch+1) == 1:
        lr = 0.001
    if (epoch+1)%5==0:
        return lr*0.98
    else:
        return lr

lrschedule=LearningRateScheduler(changeLearningRate, verbose=1)

# %%
reduce_lr=ReduceLROnPlateau(monitor='root_mean_squared_error', factor=0.98,patience=3,verbose=1,mode='min')

# %%
callback_list=[reduce_lr,lrschedule,earlystop]

# %% [markdown]
# ### Build Model

# %%
input_layer = Input(shape=(1, 16),name='input_layer')
lstm_1 = Bidirectional(LSTM(400, return_sequences=True,activation='relu'),name='lstm_1')(input_layer)
dropout_1 = Dropout(0.25,name='dropout_1')(lstm_1)
lstm_2 = Bidirectional(LSTM(500, return_sequences=True,activation='relu'),name='lstm_2')(dropout_1)
dropout_2 = Dropout(0.3,name='dropout_2')(lstm_2)

output_layer = Dense(1,name='output_layer')(dropout_2)

model=Model(inputs=input_layer,outputs=output_layer)
adam=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-07)
model.compile(optimizer=adam, loss='log_cosh',metrics=[tf.keras.metrics.RootMeanSquaredError(),'mae'])

# %%
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 16)]           0
# _________________________________________________________________
# lstm_1 (Bidirectional)       (None, 1, 800)            1334400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 800)            0
# _________________________________________________________________
# lstm_2 (Bidirectional)       (None, 1, 1000)           5204000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1000)           0
# _________________________________________________________________
# output_layer (Dense)         (None, 1, 1)              1001
# =================================================================
# Total params: 6,539,401
# Trainable params: 6,539,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
bilstm_date_array = []
bilstm_y_test_array = []
bilstm_y_test_pred_array = []
bilstm_batch_id_array = []
bilstm_batch_id_array_result = []
bilstm_batch_mae_train_array = []
bilstm_batch_rmse_train_array = []
bilstm_batch_mae_test_array = []
bilstm_batch_rmse_test_array = []

for i in range(len(train_splits)):
    print(f'Batch No. {i+1} of {len(train_splits)}')
    print('Train Data From',train_splits[i]['Date'].iloc[0],'-',train_splits[i]['next_day_closing_price'].min(),
          'to',train_splits[i]['Date'].iloc[-1],'-',train_splits[i]['next_day_closing_price'].max())
    
    print('Test Data From',test_splits[i]['Date'].iloc[0],'-',test_splits[i]['next_day_closing_price'].min(),
          'to',test_splits[i]['Date'].iloc[-1],'-',test_splits[i]['next_day_closing_price'].max())
    
    del model
    K.clear_session()
    tf.compat.v1.reset_default_graph()

    model=Model(inputs=input_layer,outputs=output_layer)
    model.compile(optimizer=adam, loss='Huber',metrics=[tf.keras.metrics.RootMeanSquaredError(),'mae'])
    Xtrain_split = train_splits[i].drop(['next_day_closing_price','Date'],axis=1).values
    Xtest_split = test_splits[i].drop(['next_day_closing_price','Date'],axis=1).values

    ytrain_split = train_splits[i]['next_day_closing_price'].reset_index(drop=True).values
    ytest_split = test_splits[i]['next_day_closing_price'].reset_index(drop=True).values

    Xtrain_split=np.reshape(Xtrain_split,(Xtrain_split.shape[0],1,Xtrain_split.shape[1]))
    Xtest_split=np.reshape(Xtest_split,(Xtest_split.shape[0],1,Xtest_split.shape[1]))

    model.fit(Xtrain_split,ytrain_split,epochs=500,batch_size=32,verbose=2,
              callbacks = [reduce_lr,lrschedule,earlystop])
    #model.save(f'/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/BI-LSTM/bilstm_{i+1}')
    ytrain_pred = model.predict(Xtrain_split).reshape(-1,1)
    ytest_pred = model.predict(Xtest_split).reshape(-1,1)
    
    MAE_train,RMSE_train = calculate_metrics(ytrain_split,ytrain_pred)
    MAE_test,RMSE_test = calculate_metrics(ytest_split,ytest_pred)

    bilstm_date_array.extend(test_splits[i]['Date'])
    bilstm_y_test_array.extend(test_splits[i]['next_day_closing_price'])
    bilstm_y_test_pred_array.extend((ytest_pred.flatten()))
    bilstm_batch_id_array.extend([i]*len(test_splits[i]))

    bilstm_batch_id_array_result.append(i)
    bilstm_batch_mae_train_array.append(MAE_train)
    bilstm_batch_rmse_train_array.append(RMSE_train)
    bilstm_batch_mae_test_array.append(MAE_test)
    bilstm_batch_rmse_test_array.append(RMSE_test)
    print('*'*100)

bilstm_result_test_df = pd.DataFrame()
bilstm_result_test_df['batch_id'] = bilstm_batch_id_array
bilstm_result_test_df['Date'] = bilstm_date_array
bilstm_result_test_df['y_test'] = bilstm_y_test_array
bilstm_result_test_df['y_test_pred'] = bilstm_y_test_pred_array
bilstm_y_test_array = bilstm_result_test_df['y_test']
bilstm_y_test_pred_array = bilstm_result_test_df['y_test_pred']
bilstm_result_metrics_df = pd.DataFrame()
bilstm_result_metrics_df['batch_id'] = bilstm_batch_id_array_result
bilstm_result_metrics_df['mae_train'] = bilstm_batch_mae_train_array
bilstm_result_metrics_df['rmse_train'] = bilstm_batch_rmse_train_array
bilstm_result_metrics_df['mae_test'] = bilstm_batch_mae_test_array
bilstm_result_metrics_df['rmse_test'] = bilstm_batch_rmse_test_array
# Out:
# Batch No. 1 of 27
# Train Data From 2013-07-17 - 89.8 to 2014-11-28 - 1237.6
# Test Data From 2014-11-29 - 164.9 to 2015-03-08 - 380.6
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/500
# 16/16 - 0s - loss: 474.6458 - root_mean_squared_error: 538.6046 - mae: 475.1458
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/500
# 16/16 - 0s - loss: 473.8553 - root_mean_squared_error: 537.8794 - mae: 474.3553
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/500
# 16/16 - 0s - loss: 470.3010 - root_mean_squared_error: 534.5863 - mae: 470.8010
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/500
# 16/16 - 0s - loss: 456.3382 - root_mean_squared_error: 522.0500 - mae: 456.8382
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009800000465475024.
# Epoch 5/500
# 16/16 - 0s - loss: 407.4003 - root_mean_squared_error: 477.0562 - mae: 407.9003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 6/500
# 16/16 - 0s - loss: 293.2263 - root_mean_squared_error: 372.9387 - mae: 293.7230
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 7/500
# 16/16 - 0s - loss: 186.5247 - root_mean_squared_error: 249.2774 - mae: 187.0234
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 8/500
# 16/16 - 0s - loss: 172.3214 - root_mean_squared_error: 218.7269 - mae: 172.8206
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009800000116229057.
# Epoch 9/500
# 16/16 - 0s - loss: 166.7525 - root_mean_squared_error: 217.1754 - mae: 167.2519
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009604000113904476.
# Epoch 10/500
# 16/16 - 0s - loss: 163.9432 - root_mean_squared_error: 219.4796 - mae: 164.4421
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 11/500
# 16/16 - 0s - loss: 159.8362 - root_mean_squared_error: 213.1254 - mae: 160.3355
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 12/500
# 16/16 - 0s - loss: 157.9173 - root_mean_squared_error: 210.6051 - mae: 158.4167
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 13/500
# 16/16 - 0s - loss: 156.5451 - root_mean_squared_error: 209.4264 - mae: 157.0451
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009604000370018184.
# Epoch 14/500
# 16/16 - 0s - loss: 151.7457 - root_mean_squared_error: 204.3439 - mae: 152.2447
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0009411920362617821.
# Epoch 15/500
# 16/16 - 0s - loss: 149.9020 - root_mean_squared_error: 203.7699 - mae: 150.4004
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009411920327693224.
# Epoch 16/500
# 16/16 - 0s - loss: 146.4678 - root_mean_squared_error: 198.5608 - mae: 146.9675
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0009411920327693224.
# Epoch 17/500
# 16/16 - 0s - loss: 143.2806 - root_mean_squared_error: 193.6634 - mae: 143.7805
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009411920327693224.
# Epoch 18/500
# 16/16 - 0s - loss: 140.2323 - root_mean_squared_error: 194.3911 - mae: 140.7318
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.
#
# Epoch 00146: LearningRateScheduler reducing learning rate to 0.00037918539601378143.
# Epoch 146/500
# 16/16 - 0s - loss: 41.1346 - root_mean_squared_error: 67.9578 - mae: 41.6304
#
# Epoch 00147: LearningRateScheduler reducing learning rate to 0.00037918539601378143.
# Epoch 147/500
#
# Epoch 00147: ReduceLROnPlateau reducing learning rate to 0.0003716016880935058.
# 16/16 - 0s - loss: 40.1993 - root_mean_squared_error: 66.0663 - mae: 40.6961
#
# Epoch 00148: LearningRateScheduler reducing learning rate to 0.0003716016944963485.
# Epoch 148/500
# 16/16 - 0s - loss: 42.3526 - root_mean_squared_error: 68.6157 - mae: 42.8470
#
# Epoch 00149: LearningRateScheduler reducing learning rate to 0.0003716016944963485.
# Epoch 149/500
# 16/16 - 0s - loss: 40.7549 - root_mean_squared_error: 66.8826 - mae: 41.2492
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 0.0003641696606064215.
# Epoch 150/500
#
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 0.0003568862599786371.
# 16/16 - 0s - loss: 41.5701 - root_mean_squared_error: 67.1792 - mae: 42.0649
#
# Epoch 00151: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 151/500
# 16/16 - 0s - loss: 40.7960 - root_mean_squared_error: 66.9845 - mae: 41.2940
#
# Epoch 00152: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 152/500
# 16/16 - 0s - loss: 41.5711 - root_mean_squared_error: 68.8583 - mae: 42.0648
#
# Epoch 00153: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 153/500
# 16/16 - 0s - loss: 38.0206 - root_mean_squared_error: 64.5299 - mae: 38.5150
#
# Epoch 00154: LearningRateScheduler reducing learning rate to 0.0003568862739484757.
# Epoch 154/500
# 16/16 - 0s - loss: 40.4338 - root_mean_squared_error: 66.0611 - mae: 40.9264
#
# Epoch 00155: LearningRateScheduler reducing learning rate to 0.0003497485484695062.
# Epoch 155/500
# 16/16 - 0s - loss: 40.2649 - root_mean_squared_error: 67.1002 - mae: 40.7608
#
# Epoch 00156: LearningRateScheduler reducing learning rate to 0.0003497485595289618.
# Epoch 156/500
#
# Epoch 00156: ReduceLROnPlateau reducing learning rate to 0.0003427535883383825.
# 16/16 - 0s - loss: 41.1407 - root_mean_squared_error: 66.4002 - mae: 41.6363
#
# Epoch 00157: LearningRateScheduler reducing learning rate to 0.0003427535993978381.
# Epoch 157/500
# 16/16 - 0s - loss: 41.3216 - root_mean_squared_error: 68.6924 - mae: 41.8179
#
# Epoch 00158: LearningRateScheduler reducing learning rate to 0.0003427535993978381.
# Epoch 158/500
# 16/16 - 0s - loss: 40.1158 - root_mean_squared_error: 67.4490 - mae: 40.6087
#
# Epoch 00159: LearningRateScheduler reducing learning rate to 0.0003427535993978381.
# Epoch 159/500
#
# Epoch 00159: ReduceLROnPlateau reducing learning rate to 0.00033589852740988134.
# 16/16 - 0s - loss: 41.4953 - root_mean_squared_error: 68.2414 - mae: 41.9894
#
# Epoch 00160: LearningRateScheduler reducing learning rate to 0.00032918057055212555.
# Epoch 160/500
# 16/16 - 0s - loss: 39.8453 - root_mean_squared_error: 66.0141 - mae: 40.3415
#
# Epoch 00161: LearningRateScheduler reducing learning rate to 0.00032918056240305305.
# Epoch 161/500
# 16/16 - 0s - loss: 40.2421 - root_mean_squared_error: 66.6618 - mae: 40.7368
#
# Epoch 00162: LearningRateScheduler reducing learning rate to 0.00032918056240305305.
# Epoch 162/500
#
# Epoch 00162: ReduceLROnPlateau reducing learning rate to 0.000322596951154992.
# 16/16 - 0s - loss: 42.0433 - root_mean_squared_error: 67.9084 - mae: 42.5394
#
# Epoch 00163: LearningRateScheduler reducing learning rate to 0.00032259695581160486.
# Epoch 163/500
# 16/16 - 0s - loss: 40.7620 - root_mean_squared_error: 65.9410 - mae: 41.2543
#
# Epoch 00164: LearningRateScheduler reducing learning rate to 0.00032259695581160486.
# Epoch 164/500
# 16/16 - 0s - loss: 40.0702 - root_mean_squared_error: 68.2478 - mae: 40.5675
#
# Epoch 00165: LearningRateScheduler reducing learning rate to 0.0003161450166953728.
# Epoch 165/500
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 0.00030982211465016004.
# 16/16 - 0s - loss: 42.0673 - root_mean_squared_error: 69.1005 - mae: 42.5648
#
# Epoch 00166: LearningRateScheduler reducing learning rate to 0.00030982212047092617.
# Epoch 166/500
# 16/16 - 0s - loss: 40.1599 - root_mean_squared_error: 66.9715 - mae: 40.6520
#
# Epoch 00167: LearningRateScheduler reducing learning rate to 0.00030982212047092617.
# Epoch 167/500
# 16/16 - 0s - loss: 41.2233 - root_mean_squared_error: 67.3537 - mae: 41.7194
#
# Epoch 00168: LearningRateScheduler reducing learning rate to 0.00030982212047092617.
# Epoch 168/500
#
# Epoch 00168: ReduceLROnPlateau reducing learning rate to 0.0003036256780615076.
# 16/16 - 0s - loss: 40.2483 - root_mean_squared_error: 65.4954 - mae: 40.7447
#
# Epoch 00169: LearningRateScheduler reducing learning rate to 0.0003036256821360439.
# Epoch 169/500
# 16/16 - 0s - loss: 40.2162 - root_mean_squared_error: 66.8144 - mae: 40.7106
#
# Epoch 00170: LearningRateScheduler reducing learning rate to 0.000297553168493323.
# Epoch 170/500
# 16/16 - 0s - loss: 41.5357 - root_mean_squared_error: 68.9348 - mae: 42.0310
#
# Epoch 00171: LearningRateScheduler reducing learning rate to 0.0002975531679112464.
# Epoch 171/500
#
# Epoch 00171: ReduceLROnPlateau reducing learning rate to 0.0002916021045530215.
# 16/16 - 0s - loss: 40.7579 - root_mean_squared_error: 66.8082 - mae: 41.2519
#
# Epoch 00172: LearningRateScheduler reducing learning rate to 0.0002916021039709449.
# Epoch 172/500
# 16/16 - 0s - loss: 40.9629 - root_mean_squared_error: 66.0116 - mae: 41.4576
#
# Epoch 00173: LearningRateScheduler reducing learning rate to 0.0002916021039709449.
# Epoch 173/500
# 16/16 - 0s - loss: 40.1692 - root_mean_squared_error: 64.8045 - mae: 40.6663
#
# Epoch 00174: LearningRateScheduler reducing learning rate to 0.0002916021039709449.
# Epoch 174/500
#
# Epoch 00174: ReduceLROnPlateau reducing learning rate to 0.000285770061891526.
# 16/16 - 0s - loss: 38.3958 - root_mean_squared_error: 65.1658 - mae: 38.8882
# Epoch 00175: LearningRateScheduler reducing learning rate to 0.0002800546732032672.
# Epoch 175/500
# 16/16 - 0s - loss: 41.7536 - root_mean_squared_error: 68.5335 - mae: 42.2487
#
# Epoch 00176: LearningRateScheduler reducing learning rate to 0.000280054664472118.
# Epoch 176/500
# 16/16 - 0s - loss: 40.1595 - root_mean_squared_error: 66.3337 - mae: 40.6555
#
# Epoch 00177: LearningRateScheduler reducing learning rate to 0.000280054664472118.
# Epoch 177/500
#
# Epoch 00177: ReduceLROnPlateau reducing learning rate to 0.00027445357118267567.
# 16/16 - 0s - loss: 39.9458 - root_mean_squared_error: 65.0921 - mae: 40.4415
#
# Epoch 00178: LearningRateScheduler reducing learning rate to 0.0002744535740930587.
# Epoch 178/500
# 16/16 - 0s - loss: 40.3810 - root_mean_squared_error: 66.4541 - mae: 40.8767
#
# Epoch 00179: LearningRateScheduler reducing learning rate to 0.0002744535740930587.
# Epoch 179/500
# 16/16 - 0s - loss: 39.9618 - root_mean_squared_error: 64.7967 - mae: 40.4569
#
# Epoch 00180: LearningRateScheduler reducing learning rate to 0.0002689645026111975.
# Epoch 180/500
#
# Epoch 00180: ReduceLROnPlateau reducing learning rate to 0.0002635852142702788.
# 16/16 - 0s - loss: 39.0456 - root_mean_squared_error: 64.5618 - mae: 39.5378
#
# Epoch 00181: LearningRateScheduler reducing learning rate to 0.0002635852142702788.
# Epoch 181/500
# 16/16 - 0s - loss: 39.5788 - root_mean_squared_error: 64.7178 - mae: 40.0758
#
# Epoch 00182: LearningRateScheduler reducing learning rate to 0.0002635852142702788.
# Epoch 182/500
# 16/16 - 0s - loss: 39.6815 - root_mean_squared_error: 66.2284 - mae: 40.1769
#
# Epoch 00183: LearningRateScheduler reducing learning rate to 0.0002635852142702788.
# Epoch 183/500
#
# Epoch 00183: ReduceLROnPlateau reducing learning rate to 0.0002583135099848732.
# 16/16 - 0s - loss: 40.0716 - root_mean_squared_error: 65.5448 - mae: 40.5678
#
# Epoch 00184: LearningRateScheduler reducing learning rate to 0.0002583135210443288.
# Epoch 184/500
# 16/16 - 0s - loss: 39.8304 - root_mean_squared_error: 64.5668 - mae: 40.3249
#
# Epoch 00185: LearningRateScheduler reducing learning rate to 0.00025314725062344225.
# Epoch 185/500
# 16/16 - 0s - loss: 40.3395 - root_mean_squared_error: 66.6896 - mae: 40.8373
#
# Epoch 00186: LearningRateScheduler reducing learning rate to 0.0002531472418922931.
# Epoch 186/500
#
# Epoch 00186: ReduceLROnPlateau reducing learning rate to 0.0002480842970544472.
# 16/16 - 0s - loss: 41.8797 - root_mean_squared_error: 69.7869 - mae: 42.3762
#
# Epoch 00187: LearningRateScheduler reducing learning rate to 0.00024808431044220924.
# Epoch 187/500
# 16/16 - 0s - loss: 39.1551 - root_mean_squared_error: 63.8950 - mae: 39.6497
#
# Epoch 00188: LearningRateScheduler reducing learning rate to 0.00024808431044220924.
# Epoch 188/500
# 16/16 - 0s - loss: 40.3925 - root_mean_squared_error: 65.8630 - mae: 40.8884
#
# Epoch 00189: LearningRateScheduler reducing learning rate to 0.00024808431044220924.
# Epoch 189/500
# 16/16 - 0s - loss: 40.8972 - root_mean_squared_error: 68.8406 - mae: 41.3888
#
# Epoch 00190: LearningRateScheduler reducing learning rate to 0.00024312262423336505.
# Epoch 190/500
#
# Epoch 00190: ReduceLROnPlateau reducing learning rate to 0.00023826017859391866.
# 16/16 - 0s - loss: 40.1948 - root_mean_squared_error: 65.1686 - mae: 40.6892
#
# Epoch 00191: LearningRateScheduler reducing learning rate to 0.00023826018150430173.
# Epoch 191/500
# 16/16 - 0s - loss: 39.4989 - root_mean_squared_error: 64.7107 - mae: 39.9948
#
# Epoch 00192: LearningRateScheduler reducing learning rate to 0.00023826018150430173.
# Epoch 192/500
# 16/16 - 0s - loss: 41.0733 - root_mean_squared_error: 67.0703 - mae: 41.5676
#
# Epoch 00193: LearningRateScheduler reducing learning rate to 0.00023826018150430173.
# Epoch 193/500
#
# Epoch 00193: ReduceLROnPlateau reducing learning rate to 0.00023349497787421568.
# 16/16 - 0s - loss: 40.7305 - root_mean_squared_error: 67.9510 - mae: 41.2265
#
# Epoch 00194: LearningRateScheduler reducing learning rate to 0.00023349498223979026.
# Epoch 194/500
# 16/16 - 0s - loss: 40.1960 - root_mean_squared_error: 64.8563 - mae: 40.6918
#
# Epoch 00195: LearningRateScheduler reducing learning rate to 0.00022882508259499445.
# Epoch 195/500
# 16/16 - 0s - loss: 39.1172 - root_mean_squared_error: 63.9082 - mae: 39.6154
#
# Epoch 00196: LearningRateScheduler reducing learning rate to 0.00022882508346810937.
# Epoch 196/500
#
# Epoch 00196: ReduceLROnPlateau reducing learning rate to 0.00022424858179874717.
# 16/16 - 0s - loss: 38.9254 - root_mean_squared_error: 64.2459 - mae: 39.4193
#
# Epoch 00197: LearningRateScheduler reducing learning rate to 0.00022424857888836414.
# Epoch 197/500
# 16/16 - 0s - loss: 38.9715 - root_mean_squared_error: 63.7911 - mae: 39.4671
#
# Epoch 00198: LearningRateScheduler reducing learning rate to 0.00022424857888836414.
# Epoch 198/500
# 16/16 - 0s - loss: 42.8748 - root_mean_squared_error: 69.0558 - mae: 43.3709
#
# Epoch 00199: LearningRateScheduler reducing learning rate to 0.00022424857888836414.
# Epoch 199/500
# 16/16 - 0s - loss: 40.5457 - root_mean_squared_error: 65.9475 - mae: 41.0424
#
# Epoch 00200: LearningRateScheduler reducing learning rate to 0.00021976360731059685.
# Epoch 200/500
#
# Epoch 00200: ReduceLROnPlateau reducing learning rate to 0.0002153683337382972.
# 16/16 - 0s - loss: 41.1145 - root_mean_squared_error: 66.2699 - mae: 41.6108
#
# Epoch 00201: LearningRateScheduler reducing learning rate to 0.00021536833082791418.
# Epoch 201/500
# 16/16 - 0s - loss: 39.5442 - root_mean_squared_error: 65.8175 - mae: 40.0400
#
# Epoch 00202: LearningRateScheduler reducing learning rate to 0.00021536833082791418.
# Epoch 202/500
# 16/16 - 0s - loss: 39.5230 - root_mean_squared_error: 64.9992 - mae: 40.0181
#
# Epoch 00203: LearningRateScheduler reducing learning rate to 0.00021536833082791418.
# Epoch 203/500
#
# Epoch 00203: ReduceLROnPlateau reducing learning rate to 0.0002110609642113559.
# 16/16 - 0s - loss: 41.1795 - root_mean_squared_error: 67.7753 - mae: 41.6738
#
# Epoch 00204: LearningRateScheduler reducing learning rate to 0.0002110609639203176.
# Epoch 204/500
# 16/16 - 0s - loss: 40.1658 - root_mean_squared_error: 66.3353 - mae: 40.6611
#
# Epoch 00205: LearningRateScheduler reducing learning rate to 0.00020683974464191123.
# Epoch 205/500
# 16/16 - 0s - loss: 39.5394 - root_mean_squared_error: 64.3660 - mae: 40.0375
#
# Epoch 00206: LearningRateScheduler reducing learning rate to 0.00020683974435087293.
# Epoch 206/500
#
# Epoch 00206: ReduceLROnPlateau reducing learning rate to 0.00020270294946385546.
# 16/16 - 0s - loss: 38.9567 - root_mean_squared_error: 65.5216 - mae: 39.4478
#
# Epoch 00207: LearningRateScheduler reducing learning rate to 0.00020270295499358326.
# Epoch 207/500
# 16/16 - 0s - loss: 40.0286 - root_mean_squared_error: 65.2069 - mae: 40.5262
#
# Epoch 00208: LearningRateScheduler reducing learning rate to 0.00020270295499358326.
# Epoch 208/500
# 16/16 - 0s - loss: 38.9482 - root_mean_squared_error: 65.8066 - mae: 39.4445
#
# Epoch 00209: LearningRateScheduler reducing learning rate to 0.00020270295499358326.
# Epoch 209/500
#
# Epoch 00209: ReduceLROnPlateau reducing learning rate to 0.0001986488958937116.
# 16/16 - 0s - loss: 39.6345 - root_mean_squared_error: 64.6210 - mae: 40.1313
#
# Epoch 00210: LearningRateScheduler reducing learning rate to 0.0001946759154088795.
# Epoch 210/500
# 16/16 - 0s - loss: 38.9508 - root_mean_squared_error: 64.8251 - mae: 39.4455
#
# Epoch 00211: LearningRateScheduler reducing learning rate to 0.0001946759148268029.
# Epoch 211/500
# 16/16 - 0s - loss: 40.6746 - root_mean_squared_error: 65.7551 - mae: 41.1715
#
# Epoch 00212: LearningRateScheduler reducing learning rate to 0.0001946759148268029.
# Epoch 212/500
# 16/16 - 0s - loss: 37.7118 - root_mean_squared_error: 62.6678 - mae: 38.2067
#
# Epoch 00213: LearningRateScheduler reducing learning rate to 0.0001946759148268029.
# Epoch 213/500
# 16/16 - 0s - loss: 39.6305 - root_mean_squared_error: 67.1008 - mae: 40.1248
#
# Epoch 00214: LearningRateScheduler reducing learning rate to 0.0001946759148268029.
# Epoch 214/500
# 16/16 - 0s - loss: 39.5903 - root_mean_squared_error: 64.8967 - mae: 40.0867
#
# Epoch 00215: LearningRateScheduler reducing learning rate to 0.00019078239653026684.
# Epoch 215/500
#
# Epoch 00215: ReduceLROnPlateau reducing learning rate to 0.00018696674203965812.
# 16/16 - 0s - loss: 40.3140 - root_mean_squared_error: 65.5573 - mae: 40.8111
# Epoch 00216: LearningRateScheduler reducing learning rate to 0.000186966746696271.
# Epoch 216/500
# 16/16 - 0s - loss: 39.0464 - root_mean_squared_error: 64.8546 - mae: 39.5425
#
# Epoch 00217: LearningRateScheduler reducing learning rate to 0.000186966746696271.
# Epoch 217/500
# 16/16 - 0s - loss: 39.8801 - root_mean_squared_error: 64.5984 - mae: 40.3766
#
# Epoch 00218: LearningRateScheduler reducing learning rate to 0.000186966746696271.
# Epoch 218/500
#
# Epoch 00218: ReduceLROnPlateau reducing learning rate to 0.00018322741176234557.
# 16/16 - 0s - loss: 41.2781 - root_mean_squared_error: 66.7627 - mae: 41.7755
#
# Epoch 00219: LearningRateScheduler reducing learning rate to 0.00018322741379961371.
# Epoch 219/500
# 16/16 - 0s - loss: 38.9920 - root_mean_squared_error: 65.0005 - mae: 39.4876
#
# Epoch 00220: LearningRateScheduler reducing learning rate to 0.00017956286552362144.
# Epoch 220/500
# 16/16 - 0s - loss: 39.9515 - root_mean_squared_error: 66.3479 - mae: 40.4475
#
# Epoch 00221: LearningRateScheduler reducing learning rate to 0.000179562863195315.
# Epoch 221/500
#
# Epoch 00221: ReduceLROnPlateau reducing learning rate to 0.0001759716059314087.
# 16/16 - 0s - loss: 40.0867 - root_mean_squared_error: 65.7507 - mae: 40.5820
#
# Epoch 00222: LearningRateScheduler reducing learning rate to 0.00017597161058802158.
# Epoch 222/500
# 16/16 - 0s - loss: 39.4696 - root_mean_squared_error: 65.5111 - mae: 39.9655
#
# Epoch 00223: LearningRateScheduler reducing learning rate to 0.00017597161058802158.
# Epoch 223/500
# 16/16 - 0s - loss: 41.0611 - root_mean_squared_error: 65.6880 - mae: 41.5595
#
# Epoch 00224: LearningRateScheduler reducing learning rate to 0.00017597161058802158.
# Epoch 224/500
#
# Epoch 00224: ReduceLROnPlateau reducing learning rate to 0.00017245217837626113.
# 16/16 - 0s - loss: 38.1092 - root_mean_squared_error: 62.9732 - mae: 38.6042
#
# Epoch 00225: LearningRateScheduler reducing learning rate to 0.00016900312824873252.
# Epoch 225/500
# 16/16 - 0s - loss: 38.9250 - root_mean_squared_error: 63.9960 - mae: 39.4199
#
# Epoch 00226: LearningRateScheduler reducing learning rate to 0.00016900313494261354.
# Epoch 226/500
# 16/16 - 0s - loss: 39.7074 - root_mean_squared_error: 64.4274 - mae: 40.2026
#
# Epoch 00227: LearningRateScheduler reducing learning rate to 0.00016900313494261354.
# Epoch 227/500
#
# Epoch 00227: ReduceLROnPlateau reducing learning rate to 0.00016562307224376126.
# 16/16 - 0s - loss: 39.4862 - root_mean_squared_error: 64.4964 - mae: 39.9861
#
# Epoch 00228: LearningRateScheduler reducing learning rate to 0.0001656230742810294.
# Epoch 228/500
# 16/16 - 0s - loss: 38.7123 - root_mean_squared_error: 62.8212 - mae: 39.2072
#
# Epoch 00229: LearningRateScheduler reducing learning rate to 0.0001656230742810294.
# Epoch 229/500
# 16/16 - 0s - loss: 38.8381 - root_mean_squared_error: 64.6077 - mae: 39.3336
#
# Epoch 00230: LearningRateScheduler reducing learning rate to 0.0001623106127954088.
# Epoch 230/500
#
# Epoch 00230: ReduceLROnPlateau reducing learning rate to 0.0001590643951203674.
# 16/16 - 0s - loss: 39.6878 - root_mean_squared_error: 64.6889 - mae: 40.1830
#
# Epoch 00231: LearningRateScheduler reducing learning rate to 0.0001590643951203674.
# Epoch 231/500
# 16/16 - 0s - loss: 39.7443 - root_mean_squared_error: 65.1918 - mae: 40.2396
#
# Epoch 00232: LearningRateScheduler reducing learning rate to 0.0001590643951203674.
# Epoch 232/500
# 16/16 - 0s - loss: 40.0348 - root_mean_squared_error: 65.5940 - mae: 40.5305
#
# Epoch 00233: LearningRateScheduler reducing learning rate to 0.0001590643951203674.
# Epoch 233/500
#
# Epoch 00233: ReduceLROnPlateau reducing learning rate to 0.00015588310721796007.
# 16/16 - 0s - loss: 41.1097 - root_mean_squared_error: 65.8825 - mae: 41.6072
#
# Epoch 00234: LearningRateScheduler reducing learning rate to 0.00015588311362080276.
# Epoch 234/500
# 16/16 - 0s - loss: 39.2736 - root_mean_squared_error: 66.7185 - mae: 39.7679
#
# Epoch 00235: LearningRateScheduler reducing learning rate to 0.0001527654513483867.
# Epoch 235/500
# 16/16 - 0s - loss: 39.3303 - root_mean_squared_error: 63.7377 - mae: 39.8279
#
# Epoch 00236: LearningRateScheduler reducing learning rate to 0.00015276545309461653.
# Epoch 236/500
#
# Epoch 00236: ReduceLROnPlateau reducing learning rate to 0.0001497101440327242.
# 16/16 - 0s - loss: 40.4218 - root_mean_squared_error: 65.7955 - mae: 40.9157
#
# Epoch 00237: LearningRateScheduler reducing learning rate to 0.00014971014752518386.
# Epoch 237/500
# 16/16 - 0s - loss: 39.8955 - root_mean_squared_error: 64.2319 - mae: 40.3878
#
# Epoch 00238: LearningRateScheduler reducing learning rate to 0.00014971014752518386.
# Epoch 238/500
# 16/16 - 0s - loss: 40.0122 - root_mean_squared_error: 65.1307 - mae: 40.5095
#
# Epoch 00239: LearningRateScheduler reducing learning rate to 0.00014971014752518386.
# Epoch 239/500
#
# Epoch 00239: ReduceLROnPlateau reducing learning rate to 0.00014671594457468017.
# 16/16 - 0s - loss: 39.4225 - root_mean_squared_error: 66.4080 - mae: 39.9196
#
# Epoch 00240: LearningRateScheduler reducing learning rate to 0.0001437816265388392.
# Epoch 240/500
# 16/16 - 0s - loss: 38.7338 - root_mean_squared_error: 64.2214 - mae: 39.2324
#
# Epoch 00241: LearningRateScheduler reducing learning rate to 0.00014378162450157106.
# Epoch 241/500
# 16/16 - 0s - loss: 38.8855 - root_mean_squared_error: 65.1071 - mae: 39.3823
#
# Epoch 00242: LearningRateScheduler reducing learning rate to 0.00014378162450157106.
# Epoch 242/500
#
# Epoch 00242: ReduceLROnPlateau reducing learning rate to 0.00014090599201153963.
# 16/16 - 0s - loss: 39.0122 - root_mean_squared_error: 64.4693 - mae: 39.5040
#
# Epoch 00243: LearningRateScheduler reducing learning rate to 0.00014090599142946303.
# Epoch 243/500
# 16/16 - 0s - loss: 38.8179 - root_mean_squared_error: 64.1415 - mae: 39.3134
#
# Epoch 00244: LearningRateScheduler reducing learning rate to 0.00014090599142946303.
# Epoch 244/500
# 16/16 - 0s - loss: 40.2501 - root_mean_squared_error: 67.0568 - mae: 40.7451
#
# Epoch 00245: LearningRateScheduler reducing learning rate to 0.00013808787160087376.
# Epoch 245/500
#
# Epoch 00245: ReduceLROnPlateau reducing learning rate to 0.00013532611017581076.
# 16/16 - 0s - loss: 39.5519 - root_mean_squared_error: 65.9624 - mae: 40.0473
#
# Epoch 00246: LearningRateScheduler reducing learning rate to 0.00013532610319089144.
# Epoch 246/500
# 16/16 - 0s - loss: 39.1871 - root_mean_squared_error: 64.6406 - mae: 39.6803
#
# Epoch 00247: LearningRateScheduler reducing learning rate to 0.00013532610319089144.
# Epoch 247/500
# 16/16 - 0s - loss: 39.0649 - root_mean_squared_error: 65.1845 - mae: 39.5621
#
# Epoch 00248: LearningRateScheduler reducing learning rate to 0.00013532610319089144.
# Epoch 248/500
#
# Epoch 00248: ReduceLROnPlateau reducing learning rate to 0.00013261958112707363.
# 16/16 - 0s - loss: 39.6283 - root_mean_squared_error: 65.1867 - mae: 40.1256
#
# ...
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.000833747792057693.
# Epoch 21/500
# 16/16 - 0s - loss: 1847.9116 - root_mean_squared_error: 2552.5627 - mae: 1848.4116
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.000833747792057693.
# Epoch 22/500
# 16/16 - 0s - loss: 1812.7308 - root_mean_squared_error: 2475.9338 - mae: 1813.2308
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000833747792057693.
# Epoch 23/500
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0004110998415853828.
# Epoch 91/500
# 16/16 - 0s - loss: 1786.5273 - root_mean_squared_error: 2394.0894 - mae: 1787.0273
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0004110998415853828.
# Epoch 92/500
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.00040287784475367516.
# 16/16 - 0s - loss: 1806.0891 - root_mean_squared_error: 2462.5593 - mae: 1806.5891
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0004028778348583728.
# Epoch 93/500
# 16/16 - 0s - loss: 1777.3383 - root_mean_squared_error: 2383.0864 - mae: 1777.8383
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0004028778348583728.
# Epoch 94/500
# 16/16 - 0s - loss: 1902.4451 - root_mean_squared_error: 2636.5918 - mae: 1902.9451
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0003948202781612053.
# Epoch 95/500
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 0.0003869238594779745.
# 16/16 - 0s - loss: 1832.1914 - root_mean_squared_error: 2475.9714 - mae: 1832.6914
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.00038692387170158327.
# Epoch 96/500
# 16/16 - 0s - loss: 1796.6699 - root_mean_squared_error: 2435.1355 - mae: 1797.1699
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.00038692387170158327.
# Epoch 97/500
# 16/16 - 0s - loss: 1855.1740 - root_mean_squared_error: 2537.5784 - mae: 1855.6737
# Epoch 00097: early stopping
# ****************************************************************************************************

# %%
plot_results(bilstm_y_test_array,bilstm_y_test_pred_array,'results-test')

# %%
bilstm_result_metrics_df
# Out:
#     batch_id    mae_train   rmse_train     mae_test    rmse_test
# 0          0    33.789832    59.403455    18.561876    22.496327
# 1          1    31.196655    55.552300    17.101940    18.525204
# 2          2    17.423232    35.682946    16.549639    18.320117
# 3          3     9.493875    14.202123    15.441452    20.810645
# 4          4     8.383567    13.095379    33.127102    36.693397
# 5          5     7.166271    11.470536    13.373764    23.568914
# 6          6     8.798387    14.387770    11.043160    16.940159
# 7          7     8.238964    14.980380    19.247844    32.942000
# 8          8    11.046024    20.571629    33.049926    50.423742
# 9          9    15.504716    28.612113   293.127476   377.506648
# 10        10    39.522037    76.057686   764.672437  1116.882280
# 11        11    83.846935   157.605221  2286.237245  3018.401848
# 12        12   232.884324   484.047090   362.423222   453.711393
# 13        13   280.843788   499.060529   192.674330   261.220103
# 14        14   310.149090   510.108146   137.819545   207.892546
# 15        15   307.596597   503.597658    68.168818   120.436606
# 16        16   274.076330   485.863297   356.123385   515.616875
# 17        17   204.017131   317.263055   254.428197   377.680738
# 18        18   194.463405   317.973747   191.718156   241.566027
# 19        19   201.912322   320.478807   318.166920   486.130667
# 20        20   224.283418   364.424772   168.918861   252.842235
# 21        21   243.963256   375.722419   366.634395   582.556163
# 22        22   242.441850   372.417657  5780.957996  7773.848999
# 23        23   491.831343   980.412110  1816.177391  2359.027583
# 24        24   819.019450  1404.286618  1559.313707  1981.961340
# 25        25  1007.852987  1566.646838  1727.489242  2163.698882
# 26        26  1260.885022  1768.450822  1175.596833  1614.156301

# %%
pd.DataFrame(bilstm_result_metrics_df.mean()).drop(['batch_id'])
# Out:
#                      0
# mae_train   243.356697
# rmse_train  398.976856
# mae_test    666.597958
# rmse_test   894.291027

# %%
bilstm_result_metrics_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/bilstm_result_metrics_20210922.csv')
bilstm_result_test_df.to_csv('/content/drive/MyDrive/Self Case studies/CS01 Bitcoin Price Forecasting/bilstm_result_test_20210922.csv')
